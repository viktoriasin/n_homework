# %% [markdown]
# # Функции в Pandas

# %%
import pandas as pd

# %%
stats = pd.read_excel('ad_campaigns.xlsx')
stats.head()
# Out:
#      Название группы                            Фраза (с минус-словами)  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    Продуктивность  ID объявления                      Заголовок  \
# 0             4.5     2101704995  МРТ на Менделеевской от 2000₽
# 1             4.5     2101704995  МРТ на Менделеевской от 2000₽
# 2             7.4     2101704995  МРТ на Менделеевской от 2000₽
# 3             5.0     2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4             5.0     2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                Текст  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                               Ссылка
# 0  https://awesome-site.ru/?utm_source=yandex&utm...
# 1  https://awesome-site.ru/?utm_source=yandex&utm...
# 2  https://awesome-site.ru/?utm_source=yandex&utm...
# 3  https://awesome-site.ru/?utm_source=yandex&utm...
# 4  https://awesome-site.ru/?utm_source=yandex&utm...

# %%
stats.columns = ['group', 'phrase', 'effect', 'ad_id', 'title', 'text', 'link']
stats.head()
# Out:
#                group                                             phrase  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link
# 0  https://awesome-site.ru/?utm_source=yandex&utm...
# 1  https://awesome-site.ru/?utm_source=yandex&utm...
# 2  https://awesome-site.ru/?utm_source=yandex&utm...
# 3  https://awesome-site.ru/?utm_source=yandex&utm...
# 4  https://awesome-site.ru/?utm_source=yandex&utm...

# %% [markdown]
# ### Lambda-функции
# Хотим посчитать распределение количества слов в столбце с фразами

# %%
stats['word_count'] = stats['phrase'].apply(lambda x: len(x.split(' ')))
stats.head()
# Out:
#                group                                             phrase  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link  word_count
# 0  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 1  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 2  https://awesome-site.ru/?utm_source=yandex&utm...           6
# 3  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 4  https://awesome-site.ru/?utm_source=yandex&utm...           2

# %%
# вариант с передачей всей строчки функции
# тут надо обязательно указать параметр axis = 1, чтобы рассматривал x как строчку, по умолчанию рассматривает как столбец

stats['word_count'] = stats.apply(lambda x: len(x['phrase'].split(' ')), axis=1)
stats.head()
# Out:
#                group                                             phrase  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link  word_count
# 0  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 1  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 2  https://awesome-site.ru/?utm_source=yandex&utm...           6
# 3  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 4  https://awesome-site.ru/?utm_source=yandex&utm...           2

# %%
#надо добавить эту строчку, чтобы визуализации строились прямо в браузеер
# %matplotlib inline

# %%
stats['word_count'].hist(bins=30)

# %% [markdown]
# ### Упражнение
# Поисковые запросы с каким количеством слов встречаются в наших данных чаще всего? Выведите топ-5

# %%
stats['word_count'].value_counts().head(5)
# Out:
# 3    1129
# 4     529
# 2     189
# 5     137
# 6      84
# Name: word_count, dtype: int64

# %% [markdown]
# ### Произвольные функции
# В URL кампаний есть названия. С этим надо что-то делать

# %%
# пример ссылки
url = stats.loc[0, 'link']
url
# Out:
# 'https://awesome-site.ru/?utm_source=yandex&utm_medium=cpc&utm_campaign=a825749b87&utm_content=dev_{device_type}'

# %%
from urllib import parse

# %%
parsed = parse.urlsplit(url)
parsed
# Out:
# SplitResult(scheme='https', netloc='awesome-site.ru', path='/', query='utm_source=yandex&utm_medium=cpc&utm_campaign=a825749b87&utm_content=dev_{device_type}', fragment='')

# %%
# как доставать значения

parsed.netloc
# Out:
# 'awesome-site.ru'

# %%
params = parse.parse_qs(parsed.query)
params
# Out:
# {'utm_source': ['yandex'],
#  'utm_medium': ['cpc'],
#  'utm_campaign': ['a825749b87'],
#  'utm_content': ['dev_{device_type}']}

# %%
# вот и кампании

params['utm_campaign'][0]
# Out:
# 'a825749b87'

# %%
# зачем тут везде списки?

url_with_doubles = 'https://awesome-site.ru/?a=1&a=2&a=3'

parsed = parse.urlsplit(url_with_doubles)
parse.parse_qs(parsed.query)
# Out:
# {'a': ['1', '2', '3']}

# %%
# оборачиваем все в функцию
# в качестве аргумента будет строка датафрейма

def campaign_name(row):
    """Получение названия кампании из ссылки внутри строки row"""

    parsed = parse.urlsplit(row['link'])
    params_dict = parse.parse_qs(parsed.query)

    return params_dict['utm_campaign'][0]

# %%
stats['campaign'] = stats.apply(campaign_name, axis=1)
stats.head()
# Out:
#                group                                             phrase  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link  word_count    campaign
# 0  https://awesome-site.ru/?utm_source=yandex&utm...           2  a825749b87
# 1  https://awesome-site.ru/?utm_source=yandex&utm...           2  a825749b87
# 2  https://awesome-site.ru/?utm_source=yandex&utm...           6  a825749b87
# 3  https://awesome-site.ru/?utm_source=yandex&utm...           2  9cc0c5f6ca
# 4  https://awesome-site.ru/?utm_source=yandex&utm...           2  9cc0c5f6ca

# %%
# как передать несколько аргументов

def power_up(row, n):
    """Возводит значение столбца effect в степень n"""
    return row['effect'] ** n

# %%
stats['power_up'] = stats.apply(power_up, n=3, axis=1)
stats.head()
# Out:
#                group                                             phrase  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link  word_count    campaign  \
# 0  https://awesome-site.ru/?utm_source=yandex&utm...           2  a825749b87
# 1  https://awesome-site.ru/?utm_source=yandex&utm...           2  a825749b87
# 2  https://awesome-site.ru/?utm_source=yandex&utm...           6  a825749b87
# 3  https://awesome-site.ru/?utm_source=yandex&utm...           2  9cc0c5f6ca
# 4  https://awesome-site.ru/?utm_source=yandex&utm...           2  9cc0c5f6ca
#
#    power_up
# 0    91.125
# 1    91.125
# 2   405.224
# 3   125.000
# 4   125.000

# %% [markdown]
# ### Упражнение
# В наших данных есть много объявлений с услугой МРТ (в названии группы есть слово 'мрт') круглосуточно (в тексте объявления есть '24 часа'). Выделите строки, в которых не упоминается МРТ, но прием идет круглосуточно. Сколько таких строк в датасете?

# %%
stats = pd.read_excel('ad_campaigns.xlsx')

# %%
stats.columns = ['group', 'phrase', 'effect', 'ad_id', 'title', 'text', 'link']
stats.head()
# Out:
#                group                                             phrase  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link
# 0  https://awesome-site.ru/?utm_source=yandex&utm...
# 1759  https://awesome-site.ru/?utm_source=yandex&utm...
# 1760  https://awesome-site.ru/?utm_source=yandex&utm...
# 1761  https://awesome-site.ru/?utm_source=yandex&utm...
# 1835  https://awesome-site.ru/?utm_source=yandex&utm...
# 1836  https://awesome-site.ru/?utm_source=yandex&utm...
# 1837  https://awesome-site.ru/?utm_source=yandex&utm...
# 1877  https://awesome-site.ru/?utm_source=yandex&utm...
# 1878  https://awesome-site.ru/?utm_source=yandex&utm...
# 1879  https://awesome-site.ru/?utm_source=yandex&utm...
# 1880  https://awesome-site.ru/?utm_source=yandex&utm...
# 1881  https://awesome-site.ru/?utm_source=yandex&utm...
# 1882  https://awesome-site.ru/?utm_source=yandex&utm...
# 1978  https://awesome-site.ru/?utm_source=yandex&utm...
# 1979  https://awesome-site.ru/?utm_source=yandex&utm...
# 1980  https://awesome-site.ru/?utm_source=yandex&utm...

# %%
((stats['text'].str.contains('24 часа')) & ~(stats['group'].str.contains('мрт'))).sum()
# Out:
# 39

# %% [markdown]
# # Группировки

# %%
# этот value_counts уже всех достал

stats['campaign'].value_counts().head()
# Out:
# 7f35591a28    456
# 8e77a0e565    348
# 2cc2e7d770    240
# f6d2ae1e3d    220
# e90f4db55a    218
# Name: campaign, dtype: int64

# %%
# нужно что-то более универсальное

stats.groupby('campaign').count().head()
# Out:
#             group  phrase  effect  ad_id  title  text  link  word_count  \
# campaign
# 034ada41b6      3       3       3      3      3     3     3           3
# 03fcaecd1d      2       2       2      2      2     2     2           2
# 0697a81555      2       2       2      2      2     2     2           2
# 08cdcb57a3      3       3       3      3      3     3     3           3
# 0f0ba311fb      2       2       2      2      2     2     2           2
#
#             power_up
# campaign
# 034ada41b6         3
# 03fcaecd1d         2
# 0697a81555         2
# 08cdcb57a3         3
# 0f0ba311fb         2

# %%
# тоже самое, что с value_counts

stats.groupby('campaign').count().reset_index().sort_values('group', ascending=False).head()
# Out:
#        campaign  group  phrase  effect  ad_id  title  text  link  word_count  \
# 62   7f35591a28    456     456     456    456    456   456   456         456
# 69   8e77a0e565    348     348     348    348    348   348   348         348
# 22   2cc2e7d770    240     240     240    240    240   240   240         240
# 110  f6d2ae1e3d    220     220     220    220    220   220   220         220
# 105  e90f4db55a    218     218     218    218    218   218   218         218
#
#      power_up
# 62        456
# 69        348
# 22        240
# 110       220
# 105       218

# %%
# но теперь можно менять функции ура

stats.groupby('campaign').sum().sort_values('effect').head()
# Out:
#             effect       ad_id  word_count  power_up
# campaign
# 63153306ff     2.8  2428554756           4    21.952
# f80e902d76     3.3  2101705003           2    35.937
# 5a7508fa8d     3.5  2428554764           4    42.875
# d5b16c7769     3.6  3401169381           4    46.656
# 7b17b2d188     5.8  2101705006           2   195.112

# %% [markdown]
# ### Упражнение
# Для каждой кампании campaign найдите минимальное значение столбца effect и постройте рейтинг кампаний по этим значениям, начиная с самого низкого.

# %%
stats.groupby([ 'campaign']).min().sort_values(by='effect')['effect']

# %%
# задаем несколько функций сразу

stats.groupby('campaign').agg(['min', 'max'])['effect'].head()

# %%
# разные метрики для разных столбцов

stats.groupby('campaign').agg({'effect': ['min', 'max'], 'power_up': 'mean'}).head()

# %%
# группировка по нескольким столбцам

stats.groupby(['group', 'campaign']).count().head()

# %%
# максимальное число объявлений в одной группе

stats.groupby(['group', 'campaign']).count().sort_values('phrase', ascending=False).head()
# Out:
#                                                     phrase  effect  ad_id  \
# group                                   campaign
# мрт на алексеевской кулаков переулок 13 7f35591a28       3       3      3
# мрт каширское шоссе                     7f35591a28       3       3      3
# мрт кутузовский                         7f35591a28       3       3      3
# мрт куркинское шоссе 30                 7f35591a28       3       3      3
# мрт куркино                             7f35591a28       3       3      3
#
#                                                     title  text  link  \
# group                                   campaign
# мрт на алексеевской кулаков переулок 13 7f35591a28      3     3     3
# мрт каширское шоссе                     7f35591a28      3     3     3
# мрт кутузовский                         7f35591a28      3     3     3
# мрт куркинское шоссе 30                 7f35591a28      3     3     3
# мрт куркино                             7f35591a28      3     3     3
#
#                                                     word_count  power_up
# group                                   campaign
# мрт на алексеевской кулаков переулок 13 7f35591a28           3         3
# мрт каширское шоссе                     7f35591a28           3         3
# мрт кутузовский                         7f35591a28           3         3
# мрт куркинское шоссе 30                 7f35591a28           3         3
# мрт куркино                             7f35591a28           3         3

# %% [markdown]
# ### Упражнение
# Какая кампания имеет наименьшую сумму по столбцу effect?

# %%
stats.groupby([ 'campaign']).sum().sort_values(by='effect')['effect']
# Out:
# campaign
# 8e77a0e565    1.6
# 7f35591a28    1.7
# be97523396    1.8
# d96029561c    1.8
# acc3077e55    1.9
# 2cc2e7d770    1.9
# f6d2ae1e3d    1.9
# 56f3d9eaff    1.9
# 90299cb806    1.9
# 7388fb4c7b    1.9
# e90f4db55a    1.9
# 1a39ecc6ce    1.9
# 8d3a748298    2.0
# c0c9fe22b7    2.1
# 777160ba51    2.1
# 706fcb19c3    2.2
# 9cc20f7a67    2.2
# 5680da7bdf    2.2
# 2db1121377    2.2
# 10f0dbeae4    2.2
# 6770528fff    2.3
# 9d35dc6a56    2.3
# c2e4dcddaf    2.3
# f0079349af    2.3
# 718ce6a065    2.3
# 6bdff94e84    2.3
# 1f39b7a501    2.5
# 172c17eaba    2.7
# 63153306ff    2.8
# edb6a77e3b    2.8
#              ...
# a825749b87    4.5
# c189a246bd    4.6
# 33e8b25a9e    4.8
# 2775b98c81    4.8
# 52a474fef2    4.8
# 9cc0c5f6ca    5.0
# 8c26e3c9fb    5.0
# 27d3cfb133    5.0
# 82115c21af    5.1
# b0fb5bd15c    5.3
# 22797af531    5.4
# 5ba2e2d560    5.5
# 08cdcb57a3    5.5
# 7b17b2d188    5.8
# 942cf4ac20    6.3
# 3e3a02c7b5    6.3
# da872d1fb4    6.6
# 3cba0fca70    6.7
# 9bf072c32b    7.2
# 6e8f620704    7.2
# 779ad0e7f3    7.3
# a117c5fc1b    7.4
# 8efe80b27c    7.4
# a5444a2280    7.4
# b3f52e6f64    7.5
# 9ee3e2c876    7.7
# 28d8dca4df    8.4
# eb577faed1    8.5
# d0712ff587    8.7
# 23d6da5a5a    8.7
# Name: effect, Length: 115, dtype: float64

# %% [markdown]
# # Агрегированные группировки
# Считаем метрики для пользователей, которые выставили 100 и более оценок

# %%
# в timestamp - время в формате unix time
ratings = pd.read_csv('ml-latest-small/ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %% [markdown]
# ### Упражнение
# Получите список пользователей film_fans_user_ids, которые выставили 100 и более оценок фильмам. Чтобы перевести pandas series в список можно использовать метод tolist():
#
# film_fans_user_ids = some_dataframe['userId'].tolist()

# %%
rat_filtered = ratings.groupby('userId').count().head()

# %%
rat_filtered = rat_filtered[rat_filtered['movieId'] >= 100].reset_index()
rat_filtered
# Out:
#    userId  movieId  rating  timestamp
# 0       4      204     204        204
# 1       5      100     100        100

# %%
us_list = rat_filtered['userId'].tolist()
us_list
# Out:
# [4, 5]

# %%
#yнедостаток этого метода с доп списками - все эти списки должны влезать в оперативную память
ratings[ratings['userId'].isin(us_list)]
# Out:
#      userId  movieId  rating   timestamp
# 147       4       10     4.0   949810645
# 148       4       34     5.0   949919556
# 149       4      112     5.0   949810582
# 150       4      141     5.0   949919681
# 151       4      153     4.0   949811346
# 152       4      173     3.0   949811346
# 153       4      185     3.0   949920047
# 154       4      260     5.0   949779042
# 155       4      289     4.0   949778802
# 156       4      296     5.0   949895708
# 157       4      329     3.0   949810618
# 158       4      349     5.0   949810582
# 159       4      356     5.0   949919763
# 160       4      357     5.0   949919681
# 161       4      364     5.0   949949538
# 162       4      367     4.0   949895887
# 163       4      380     3.0   949810534
# 164       4      410     3.0   949919883
# 165       4      431     3.0   949895772
# 166       4      434     4.0   949810688
# 167       4      435     1.0   949920135
# 168       4      440     4.0   949919802
# 169       4      442     4.0   949920028
# 170       4      464     4.0   949811315
# 171       4      480     5.0   949810582
# 172       4      541     5.0   949779091
# 173       4      588     5.0   949949486
# 174       4      589     5.0   949919938
# 175       4      590     3.0   949810534
# 176       4      594     5.0   949949538
# ..      ...      ...     ...         ...
# 421       5     5266     3.5  1163374995
# 422       5     5299     4.5  1163373299
# 423       5     5349     4.5  1163373606
# 424       5     5464     4.0  1163374443
# 425       5     5669     3.5  1163374206
# 426       5     5679     4.5  1163374389
# 427       5     5816     3.0  1163373688
# 428       5     5995     4.0  1163374533
# 429       5     6218     3.5  1163374491
# 430       5     6373     4.0  1163374572
# 431       5     6377     4.0  1163373626
# 432       5     6502     4.0  1163374455
# 433       5     6711     2.5  1163373238
# 434       5     6942     4.0  1163374511
# 435       5     8376     4.0  1163374742
# 436       5     8464     4.0  1163374381
# 437       5     8622     3.5  1163374118
# 438       5     8636     4.5  1163373593
# 439       5     8644     4.0  1163374426
# 440       5    30707     4.5  1163374340
# 441       5    30749     4.5  1163374702
# 442       5    30793     3.5  1163374177
# 443       5    33166     5.0  1163374211
# 444       5    33679     4.0  1163374517
# 445       5    34162     4.5  1163374227
# 446       5    35836     4.0  1163374275
# 447       5    40819     4.5  1163374283
# 448       5    41566     4.0  1163374144
# 449       5    41569     4.0  1163374167
# 450       5    48385     4.5  1163374357
#
# [304 rows x 4 columns]

# %% [markdown]
# # Сводные таблицы
# Прям как в экселе

# %%
data = pd.read_csv('ml-latest-small/ratings.csv')
data.head()

# %%
# какие оценки поставил пользователь №1

data[ data['userId'] == 1 ]['rating'].value_counts()

# %%
# а для всех пользователей сразу?

data.pivot_table(index = 'userId', columns = 'rating', values = 'timestamp', aggfunc = 'count', fill_value = 0)

# %%
# можно итоги добавить
data.pivot_table(index = 'userId', columns = 'rating', values = 'timestamp', aggfunc = 'count', fill_value = 0,
                 margins = True)

# %% [markdown]
# ### Упражнение
# Какой пользователь выставил больше всех пятерок?

# %% [markdown]
# # Объединение датафреймов
# Какой жанр имеет самые высокие рейтинги?

# %%
genres = ['Drama', 'Action', 'Thriller']

# %%
import numpy as np

# %%
ratings = pd.read_csv('ml-latest-small/ratings.csv')
ratings.head()

# %%
movies = pd.read_csv('ml-latest-small/movies.csv')
movies.head()

# %%
joined = ratings.merge(movies, on='movieId', how='left')
joined.head()

# %%
# рекомендуемая проверка на возможные дубликаты

len(ratings) == len(joined)

# %% [markdown]
# ### Немного о подводных камнях

# %%
ratings = pd.read_csv('ratings_example.txt', sep = '\t')
ratings.head()

# %%
movies = pd.read_csv('movies_example.txt', sep = '\t')
movies.head()

# %%
# ¯\_(ツ)_/¯

ratings.merge(movies, how = 'left', on = 'movieId')

# %%
movies.drop_duplicates(subset = 'movieId', keep = 'first', inplace = True)
movies.head()

# %%
ratings.merge(movies, how = 'left', on = 'movieId')

# %% [markdown]
# ### Считаем рейтинг жанров

# %%
# еще раз список жанров

genres = ['Drama', 'Action', 'Thriller']

# %%
def genres_ratings(row):
    """Возвращает рейтинг, если он есть в списке жанров данного фильма"""
    
    return pd.Series([row['rating'] if genre in row['genres'] else np.NaN for genre in genres])

# %%
joined[genres] = joined.apply(genres_ratings, axis=1)
joined.head()

# %% [markdown]
# ### Упражнение
# Выведите средний рейтинг каждого жанра из списка genres

# %% [markdown]
# # Немного про визуализации

# %% [markdown]
# ### Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('sales_data.csv', sep=';')
data

# %%
plt.plot(data['month'], data['2016'])
plt.plot(data['2017'])
plt.plot(data['2018'])

# %%
plt.plot(data['month'], data['2016'], marker='o')
plt.plot(data['2017'], linestyle='dashed')
plt.plot(data['2016'], linewidth=5)

plt.legend()

# %% [markdown]
# ### Seaborn
# http://seaborn.pydata.org/examples/

# %%
features = pd.read_csv('correlation.tsv', sep='\t')
features

# %%
# месяц сейчас не пригодится

features.drop('month', axis=1, inplace=True)
features.head()

# %%
features.corr()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
f, ax = plt.subplots(figsize=(9, 6))

sns.heatmap(features.corr())

# %%
# добавляем наглядности

f, ax = plt.subplots(figsize=(9, 6))

sns.heatmap(features.corr(), annot=True, fmt='.1f', ax=ax, cmap=sns.color_palette('coolwarm', 16))
