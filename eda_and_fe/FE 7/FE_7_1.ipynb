# %%
import seaborn as sb
import sys  
import pandas as pd
import requests
import numpy as np
import transliterate
import datetime
import time
import pickle
import matplotlib.pyplot as plt
import time
# %matplotlib inline

from bs4 import BeautifulSoup as bs
import urllib

# %%
def load_obj(name):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)

def save_obj(obj, name):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

# %%
app_id = 
access_token =

# %%
tj_id = 28261334

# %%
my_id = 

# api call and test
def vk_get_response(method, parameters, token):
    url = 'https://api.vk.com/method/' + method + '?' + parameters + '&access_token=' + token
    return(requests.get(url).json())

answer = vk_get_response(
    'users.get', 'user_ids={0}&v=4.9&lang=ru'.format(my_id), access_token
)['response']

print(answer[0]['first_name'], answer[0]['last_name'])
# Out:
# Сагатаип Карсалаев

# %%
check_group_id = tj_id * -1
check = vk_get_response(
        'wall.get', 'owner_id={0}&count=50&fields=post_type,marked_as_ads&v=4.9'.format(
            int(check_group_id)
        ),
    access_token
)

# %%
check
# Out:
# {'response': [59140,
#   {'attachments': [{'link': {'description': 'Корреспондент стал известен после видео на день ВДВ в парке Горького.',
#       'image_big': 'https://pp.userapi.com/c851328/v851328065/35a86/0_te2EGhY6E.jpg',
#       'image_src': 'https://pp.userapi.com/c851328/v851328065/35a84/JpiP0fpc448.jpg',
#       'target': 'internal',
#       'title': 'Журналист НТВ Никита Развозжаев покончил с собой. Он оставил прощальную записку во «ВКонтакте»',
#       'url': 'https://tjournal.ru/79022-zhurnalist-ntv-nikita-razvozzhaev-pokonchil-s-soboy-on-ostavil-proshchalnuyu-zapisku-vo-vkontakte'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 22},
#    'date': 1540807024,
#    'from_id': -28261334,
#    'id': 906026,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 70, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'Журналист НТВ Никита Развозжаев покончил с собой. Он оставил прощальную записку во «ВКонтакте»',
#     'share_url': 'https://tjournal.ru/79022-zhurnalist-ntv-nikita-razvozzhaev-pokonchil-s-soboy-on-ostavil-proshchalnuyu-zapisku-vo-vkontakte',
#     'type': 'share'},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 22,
#    'reposts': {'count': 5, 'user_reposted': 0},
#    'text': 'Журналист стал известен после видео на день ВДВ в парке Горького, где на него напали во время эфира.<br><br>В прощальной записке он обратился к семье, друзьям и коллегам с НТВ.',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': 'Причиной зачастую становится неправильное написание адреса.',
#       'image_big': 'https://pp.userapi.com/c851224/v851224468/32835/JjIWtEfo4Jw.jpg',
#       'image_src': 'https://pp.userapi.com/c851224/v851224468/32833/t1AZly70Ee0.jpg',
#       'target': 'internal',
#       'title': 'ГИБДД Москвы простила более 5 миллионов штрафов из-за технической ошибки',
#       'url': 'https://tjournal.ru/79020-gibdd-moskvy-prostila-bolee-5-millionov-shtrafov-iz-za-tehnicheskoy-oshibki'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 23},
#    'date': 1540804986,
#    'from_id': -28261334,
#    'id': 905986,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 51, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'ГИБДД Москвы простила более 5 миллионов штрафов из-за технической ошибки',
#     'share_url': 'https://tjournal.ru/79020-gibdd-moskvy-prostila-bolee-5-millionov-shtrafov-iz-za-tehnicheskoy-oshibki',
#     'type': 'share'},
#    'online': 0,
#    'post_source': {'type': 'api'},
#    'post_type': 'post',
#    'reply_count': 23,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': 'Проблемы возникают в том числе из-за ошибки в написании адреса — например, если он указан в неправильном порядке.',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': 'Церковь 1900 года постройки пережила революцию, советский режим и перестройку, а в 2017 её обшили сайдингом.',
#       'image_big': 'https://pp.userapi.com/c845220/v845220135/11fad6/njweeknAjbk.jpg',
#       'image_src': 'https://pp.userapi.com/c845220/v845220135/11fad4/TRGAw3fT_h0.jpg',
#       'target': 'internal',
#       'title': 'Архитектура: Деревянный храм в Чувашии после реставрации',
#       'url': 'https://tjournal.ru/79018-arhitektura-derevyannyy-hram-v-chuvashii-posle-restavracii'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 28},
#    'date': 1540803000,
#    'from_id': -28261334,
#    'id': 905938,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 120, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'Архитектура: Деревянный храм в Чувашии после реставрации',
#     'share_url': 'https://tjournal.ru/79018-arhitektura-derevyannyy-hram-v-chuvashii-posle-restavracii',
#     'type': 'share'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 28,
#    'reposts': {'count': 6, 'user_reposted': 0},
#    'text': 'Деревянный храм в Чувашии пережил революцию, СССР и перестройку, а в 2017-м его обшили синим профильным листом и поменяли окна на стеклопакеты. <br><br>И это далеко не единственный пример подобного «ремонта» архитектурных достопримечательностей.',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': 'В Сбербанке говорят, что это адресная книга и она доступна всем сотрудникам банка.',
#       'image_big': 'https://pp.userapi.com/c830708/v830708830/1bfc88/uQDhbc8kMAs.jpg',
#       'image_src': 'https://pp.userapi.com/c830708/v830708830/1bfc86/NaMqlZ5RW1k.jpg',
#       'target': 'internal',
#       'title': 'Данные 420 тысяч сотрудников Сбербанка опубликовали в открытом доступе. Банк утверждает, что угрозы нет',
#       'url': 'https://tjournal.ru/79019-dannye-420-tysyach-sotrudnikov-sberbanka-opublikovali-v-otkrytom-dostupe-bank-utverzhdaet-chto-ugrozy-net'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 28},
#    'date': 1540801256,
#    'from_id': -28261334,
#    'id': 905908,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 65, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'Данные 420 тысяч сотрудников Сбербанка опубликовали в открытом доступе. Банк утверждает, что угрозы нет',
#     'share_url': 'https://tjournal.ru/79019-dannye-420-tysyach-sotrudnikov-sberbanka-opublikovali-v-otkrytom-dostupe-bank-utverzhdaet-chto-ugrozy-net',
#     'type': 'share'},
#    'online': 0,
#    'post_source': {'type': 'api'},
#    'post_type': 'post',
#    'reply_count': 28,
#    'reposts': {'count': 2, 'user_reposted': 0},
#    'text': 'Из Сбербанка утекла база имён и адресов электронной почты 420 тысяч сотрудников. В банке об этом знают, но утверждают, что никакой угрозы нет — это адресная книга, доступная всем сотрудникам.',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': 'Американские рэперы издеваются друг над другом по-крупному.',
#       'image_big': 'https://pp.userapi.com/c848628/v848628063/a84dc/xxpBNyfCEdU.jpg',
#       'image_src': 'https://pp.userapi.com/c848628/v848628063/a84da/LP9Ean0Dqqc.jpg',
#       'target': 'internal',
#       'title': '50 Cent купил 200 билетов на концерт Ja Rule, чтобы оставить места пустыми',
#       'url': 'https://tjournal.ru/79017-50-cent-kupil-200-biletov-na-koncert-ja-rule-chtoby-ostavit-mesta-pustymi'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 19},
#    'date': 1540798296,
#    'from_id': -28261334,
#    'id': 905873,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 281, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': '50 Cent купил 200 билетов на концерт Ja Rule, чтобы оставить места пустыми',
#     'share_url': 'https://tjournal.ru/79017-50-cent-kupil-200-biletov-na-koncert-ja-rule-chtoby-ostavit-mesta-pustymi',
#     'type': 'share'},
#    'online': 0,
#    'post_source': {'type': 'api'},
#    'post_type': 'post',
#    'reply_count': 19,
#    'reposts': {'count': 2, 'user_reposted': 0},
#    'text': '50 Cent потратил 3 тысячи долларов, зато поиздевался над старым врагом.',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': 'Выступает за легализацию оружия и против мигрантов, служил десантником и поддерживает Трампа.',
#       'image_big': 'https://sun1-3.userapi.com/c831308/v831308974/1c7802/YneMlCrhB7I.jpg',
#       'image_src': 'https://sun1-1.userapi.com/c831308/v831308974/1c7800/f_yOUUCZDeM.jpg',
#       'target': 'internal',
#       'title': 'На выборах в Бразилии победил ультраправый кандидат Болсонару',
#       'url': 'https://tjournal.ru/79013-na-vyborah-v-brazilii-pobedil-ultrapravyy-kandidat-bolsonaru'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 62},
#    'date': 1540796779,
#    'from_id': -28261334,
#    'id': 905837,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 170, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'На выборах в Бразилии победил ультраправый кандидат Болсонару',
#     'share_url': 'https://tjournal.ru/79013-na-vyborah-v-brazilii-pobedil-ultrapravyy-kandidat-bolsonaru',
#     'type': 'share'},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 62,
#    'reposts': {'count': 7, 'user_reposted': 0},
#    'text': 'В Бразилии новый президент: он называет Трампа своим кумиром, а себя — сторонником военной диктатуры для борьбы с коррупцией.',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': 'Что говорят учёные о связи видеоигр и агрессии.',
#       'image_big': 'https://pp.userapi.com/c851020/v851020680/2f9af/L2XWXWBr-3U.jpg',
#       'image_src': 'https://pp.userapi.com/c851020/v851020680/2f9ad/IHoqdoHTF3s.jpg',
#       'target': 'internal',
#       'title': 'Вековой спор: порождают ли игры желание убивать',
#       'url': 'https://dtf.ru/games/29919-vekovoy-spor-porozhdayut-li-igry-zhelanie-ubivat'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 44},
#    'date': 1540795553,
#    'from_id': -28261334,
#    'id': 905797,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 190, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'Вековой спор: порождают ли игры желание убивать',
#     'share_url': 'https://dtf.ru/games/29919-vekovoy-spor-porozhdayut-li-igry-zhelanie-ubivat',
#     'type': 'share'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 44,
#    'reposts': {'count': 7, 'user_reposted': 0},
#    'text': 'На фоне снова и снова разгорающихся споров о том, как связаны увлечение видеоиграми и тяга к реальному насилию, DTF рассказывает, откуда вообще появилось это убеждение и что думают о нём учёные.',
#    'to_id': -28261334},
#   {'attachments': [{'photo': {'access_key': '7cb7f5c5871921b848',
#       'aid': -7,
#       'created': 1540793570,
#       'height': 780,
#       'owner_id': -28261334,
#       'pid': 456248123,
#       'src': 'https://pp.userapi.com/c848624/v848624608/aa2de/NuuttfBTVuA.jpg',
#       'src_big': 'https://pp.userapi.com/c848624/v848624608/aa2df/PZXaHeSjfiY.jpg',
#       'src_small': 'https://pp.userapi.com/c848624/v848624608/aa2dd/PX5uWqyrZOw.jpg',
#       'src_xbig': 'https://pp.userapi.com/c848624/v848624608/aa2e0/ad4FW1Ubl8I.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c848624/v848624608/aa2e1/ipIGhRpfT2k.jpg',
#       'text': '',
#       'user_id': 100,
#       'width': 1040},
#      'type': 'photo'},
#     {'photo': {'access_key': '98dd6aa5fe1014503a',
#       'aid': -7,
#       'created': 1540793570,
#       'height': 810,
#       'owner_id': -28261334,
#       'pid': 456248124,
#       'src': 'https://pp.userapi.com/c848624/v848624608/aa2f0/85AZUVrrVdQ.jpg',
#       'src_big': 'https://pp.userapi.com/c848624/v848624608/aa2f1/NUe1Qk1sUe4.jpg',
#       'src_small': 'https://pp.userapi.com/c848624/v848624608/aa2ef/3szDxeVeQ88.jpg',
#       'src_xbig': 'https://pp.userapi.com/c848624/v848624608/aa2f2/RfjTVcBLgOA.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c848624/v848624608/aa2f3/awlOcuykKGA.jpg',
#       'text': '',
#       'user_id': 100,
#       'width': 1080},
#      'type': 'photo'}],
#    'comments': {'can_post': 1, 'count': 7},
#    'date': 1540793570,
#    'from_id': -28261334,
#    'id': 905787,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 61, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456248124,
#     'owner_id': -28261334,
#     'thumb_src': 'https://pp.userapi.com/c848624/v848624608/aa2f0/85AZUVrrVdQ.jpg',
#     'type': 'photo'},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 7,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': 'Утро понедельника, TJ. К новостям последних часов: <br><br>— В Индонезии разбился «Боинг» с 188 людьми на борту. Он упал в море почти сразу после вылета https://tjournal.ru/79015 <br><br>— IBM объявила о покупке разработчика облачных решений Red Hat за 34 миллиарда долларов. Так IBM станет самым крупным провайдером на быстро растущем рынке tjournal.ru/79014<br><br>— Rambler Group полностью откажется от брендов «Синема парк» и «Формула кино». Кинотеатры переименует в Okko tjournal.ru/79016<br><br>  На снимке обломки и детали индонезийского «Боинга», упавшего в море. Фото местного агентства по преодолению ЧС',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': 'В декабре 2017 года между двумя игроками возник спор за 1,5 доллара. Конфликт привёл к полицейскому штурму и одной смерти.',
#       'image_big': 'https://pp.userapi.com/c852124/v852124993/33a49/Sr4NtlWHgak.jpg',
#       'image_src': 'https://pp.userapi.com/c852124/v852124993/33a47/El6bpVaIyzs.jpg',
#       'target': 'internal',
#       'title': 'Пранк из видеоигры, переросший в реальную стрельбу: история гибели американца из-за случайной ссоры ',
#       'url': 'https://tjournal.ru/78923'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 13},
#    'date': 1540774801,
#    'from_id': -28261334,
#    'id': 905766,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 166, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'Пранк из видеоигры, переросший в реальную стрельбу: история гибели американца из-за случайной ссоры ',
#     'share_url': 'https://tjournal.ru/78923',
#     'type': 'share'},
#    'online': 1,
#    'post_source': {'platform': 'iphone', 'type': 'api'},
#    'post_type': 'post',
#    'reply_count': 13,
#    'reposts': {'count': 11, 'user_reposted': 0},
#    'text': 'Натравливать полицию на неприятелей — это распространённая тактика в американском видеоигровом сообществе. В декабре прошлого года двое игроков в Call of Duty поссорились из-за 1,5 доллара, и оба решили отомстить друг другу с помощью полиции.<br><br>Вот большая история о том, как локальный конфликт привёл к убийству отца двоих детей и переменам в законодательстве.',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': 'Лучше пещеры Бэтмена.',
#       'image_big': 'https://pp.userapi.com/c830708/v830708933/1bc962/cMRxyoih3UQ.jpg',
#       'image_src': 'https://pp.userapi.com/c830708/v830708933/1bc960/oMgHwSpALP0.jpg',
#       'target': 'internal',
#       'title': 'Архитектура: «Самая роскошная пещера в мире»',
#       'url': 'https://tjournal.ru/75613-arhitektura-samaya-roskoshnaya-peshchera-v-mire'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 4},
#    'date': 1540767601,
#    'from_id': -28261334,
#    'id': 905759,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 134, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'Архитектура: «Самая роскошная пещера в мире»',
#     'share_url': 'https://tjournal.ru/75613-arhitektura-samaya-roskoshnaya-peshchera-v-mire',
#     'type': 'share'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 4,
#    'reposts': {'count': 4, 'user_reposted': 0},
#    'text': 'Лучше пещеры Бэтмена.',
#    'to_id': -28261334},
#   {'attachments': [{'photo': {'access_key': 'a14d672e7872ab3493',
#       'aid': -7,
#       'created': 1540743087,
#       'height': 233,
#       'owner_id': -28261334,
#       'pid': 456248108,
#       'post_id': 905717,
#       'src': 'https://pp.userapi.com/c848520/v848520538/a73e2/M8xsqKkdHxs.jpg',
#       'src_big': 'https://pp.userapi.com/c848520/v848520538/a73e3/3Rn12rz0tbg.jpg',
#       'src_small': 'https://pp.userapi.com/c848520/v848520538/a73e1/bJHSFdmbhaA.jpg',
#       'text': '',
#       'user_id': 100,
#       'width': 508},
#      'type': 'photo'}],
#    'comments': {'can_post': 1, 'count': 15},
#    'date': 1540751402,
#    'from_id': -28261334,
#    'id': 905717,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 520, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456248108,
#     'owner_id': -28261334,
#     'thumb_src': 'https://pp.userapi.com/c848520/v848520538/a73e2/M8xsqKkdHxs.jpg',
#     'type': 'photo'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 15,
#    'reposts': {'count': 8, 'user_reposted': 0},
#    'text': 'Неделя прошла под знаком акулы из IKEA. На случай, если вы всё пропустили, рассказываем. <br><br>https://tjournal.ru/78770',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': 'Взамен делимся парой наблюдений и мыслей.',
#       'image_big': 'https://sun1-19.userapi.com/c830409/v830409380/1c8195/ATzY6NwEOrc.jpg',
#       'image_src': 'https://sun1-6.userapi.com/c830409/v830409380/1c8193/qxBURHJ740w.jpg',
#       'target': 'internal',
#       'title': 'Мы удалили видео о беспилотнике «Яндекса» по просьбе «Яндекса»',
#       'url': 'https://tjournal.ru/79007-my-udalili-video-o-bespilotnike-yandeksa-po-prosbe-yandeksa'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 8},
#    'date': 1540747830,
#    'from_id': -28261334,
#    'id': 905692,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 82, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'Мы удалили видео о беспилотнике «Яндекса» по просьбе «Яндекса»',
#     'share_url': 'https://tjournal.ru/79007-my-udalili-video-o-bespilotnike-yandeksa-po-prosbe-yandeksa',
#     'type': 'share'},
#    'online': 0,
#    'post_source': {'type': 'api'},
#    'post_type': 'post',
#    'reply_count': 8,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': 'Видео про беспилотник «Яндекса», которым мы здесь делились месяц назад, пришлось удалить.<br><br>Зато поделимся некоторыми мыслями и наблюдениями, которые не вошли в ролик из-за его короткого формата.',
#    'to_id': -28261334},
#   {'attachments': [{'photo': {'access_key': '7fc19f25cf97611578',
#       'aid': -7,
#       'created': 1540743273,
#       'height': 1200,
#       'owner_id': -28261334,
#       'pid': 456248109,
#       'post_id': 905659,
#       'src': 'https://pp.userapi.com/c848520/v848520538/a7401/VBOnMSnBpzw.jpg',
#       'src_big': 'https://pp.userapi.com/c848520/v848520538/a7402/06N6eLWoJPc.jpg',
#       'src_small': 'https://pp.userapi.com/c848520/v848520538/a7400/bAQIt8vcNqE.jpg',
#       'src_xbig': 'https://pp.userapi.com/c848520/v848520538/a7403/kIi5rW-zZAA.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c848520/v848520538/a7404/FBNfYXVExAI.jpg',
#       'src_xxxbig': 'https://pp.userapi.com/c848520/v848520538/a7405/yxtCLK-pJzA.jpg',
#       'text': '',
#       'user_id': 100,
#       'width': 1048},
#      'type': 'photo'}],
#    'comments': {'can_post': 1, 'count': 48},
#    'date': 1540746012,
#    'from_id': -28261334,
#    'id': 905659,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 1924, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456248109,
#     'owner_id': -28261334,
#     'thumb_src': 'https://pp.userapi.com/c848520/v848520538/a7401/VBOnMSnBpzw.jpg',
#     'type': 'photo'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 48,
#    'reposts': {'count': 65, 'user_reposted': 0},
#    'text': 'Интересное фото вороны. Особенно если учесть, что это кот (via RobertMaguire_)',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': 'Авторы проекта Silo Art Trail создали серию граффити на зернохранилищах Австралии и карту специально для поклонников этой разновидности искусства.',
#       'image_big': 'https://pp.userapi.com/c852124/v852124517/31d90/BhOSbZW9Uf8.jpg',
#       'image_src': 'https://pp.userapi.com/c852124/v852124517/31d8e/5zuNoOzUKfc.jpg',
#       'target': 'internal',
#       'title': 'Фото: Граффити на австралийских зернохранилищах',
#       'url': 'https://tjournal.ru/79003-foto-graffiti-na-avstraliyskih-zernohranilishchah'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 1},
#    'date': 1540742412,
#    'from_id': -28261334,
#    'id': 905644,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 92, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'Фото: Граффити на австралийских зернохранилищах',
#     'share_url': 'https://tjournal.ru/79003-foto-graffiti-na-avstraliyskih-zernohranilishchah',
#     'type': 'share'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 1,
#    'reposts': {'count': 5, 'user_reposted': 0},
#    'text': 'Австралийские художники превратили местные зернохранилища в произведения искусства.',
#    'to_id': -28261334},
#   {'attachments': [{'photo': {'access_key': '1d6af54c8211a6c414',
#       'aid': -7,
#       'created': 1540717203,
#       'height': 339,
#       'owner_id': -28261334,
#       'pid': 456248094,
#       'post_id': 905621,
#       'src': 'https://pp.userapi.com/c851420/v851420429/33555/GYUQy_kyIpg.jpg',
#       'src_big': 'https://pp.userapi.com/c851420/v851420429/33556/_xKjfURqar8.jpg',
#       'src_small': 'https://pp.userapi.com/c851420/v851420429/33554/x8DckOvsox0.jpg',
#       'text': '',
#       'user_id': 100,
#       'width': 479},
#      'type': 'photo'}],
#    'comments': {'can_post': 1, 'count': 24},
#    'date': 1540738810,
#    'from_id': -28261334,
#    'id': 905621,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 569, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456248094,
#     'owner_id': -28261334,
#     'thumb_src': 'https://pp.userapi.com/c851420/v851420429/33555/GYUQy_kyIpg.jpg',
#     'type': 'photo'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 24,
#    'reposts': {'count': 9, 'user_reposted': 0},
#    'text': '',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': 'Статьи One way ticket: гайд по 13 странам для потенциального эмигранта и Гайд: 8 европейских стран для потенциального эмигранта не смогли вместить в себя все страны, о которых хочется рассказать. Публикуем третью часть гайда, куда включили страны, куда нечасто переезжают соотечественники.',
#       'image_big': 'https://pp.userapi.com/c852120/v852120672/300f7/JhPayPRf0fs.jpg',
#       'image_src': 'https://pp.userapi.com/c852120/v852120672/300f5/UDknUOwagsQ.jpg',
#       'target': 'internal',
#       'title': 'Гайд: семь стран в разных уголках мира для потенциального эмигранта — Личный опыт на vc.ru',
#       'url': 'https://vc.ru/life/48718-gayd-sem-stran-v-raznyh-ugolkah-mira-dlya-potencialnogo-emigranta'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 32},
#    'date': 1540735211,
#    'from_id': -28261334,
#    'id': 905600,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 675, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'Гайд: семь стран в разных уголках мира для потенциального эмигранта — Личный опыт на vc.ru',
#     'share_url': 'https://vc.ru/life/48718-gayd-sem-stran-v-raznyh-ugolkah-mira-dlya-potencialnogo-emigranta',
#     'type': 'share'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 32,
#    'reposts': {'count': 33, 'user_reposted': 0},
#    'text': 'Семь эмигрантов рассказали, каково это — переехать в не самые популярные у россиян страны: Австралию, Кубу, Эстонию, Канаду, Новую Зеландию, ОАЭ и Японию.',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': 'Хотя его никто, в общем-то, и не просил.',
#       'image_big': 'https://pp.userapi.com/c851216/v851216537/2f782/poF3Y0QZnX0.jpg',
#       'image_src': 'https://pp.userapi.com/c851216/v851216537/2f780/2cQI3WeWc3w.jpg',
#       'target': 'internal',
#       'title': 'Американец оплатил библиотеке штраф за просрочку возврата книги, взятой его матерью в 1934 году',
#       'url': 'https://tjournal.ru/78998-amerikanec-oplatil-biblioteke-shtraf-za-prosrochku-vozvrata-knigi-vzyatoy-ego-materyu-v-1934-godu'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 23},
#    'date': 1540731615,
#    'from_id': -28261334,
#    'id': 905571,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 296, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'Американец оплатил библиотеке штраф за просрочку возврата книги, взятой его матерью в 1934 году',
#     'share_url': 'https://tjournal.ru/78998-amerikanec-oplatil-biblioteke-shtraf-za-prosrochku-vozvrata-knigi-vzyatoy-ego-materyu-v-1934-godu',
#     'type': 'share'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 23,
#    'reposts': {'count': 7, 'user_reposted': 0},
#    'text': 'Библиотека была готова принять в качестве штрафа 3 доллара, но принципиальный мужчина заплатил штраф полностью — в пересчёте на рубли вышло чуть больше 100 тысяч.',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': '',
#       'image_big': 'https://pp.userapi.com/c847122/v847122545/11d266/iQG4xKbEZ0Q.jpg',
#       'image_src': 'https://pp.userapi.com/c847122/v847122545/11d264/NK88ka57zGs.jpg',
#       'target': 'internal',
#       'title': 'Пранк из видеоигры, переросший в реальную стрельбу: история гибели американца из-за случайной ссоры ',
#       'url': 'https://tjournal.ru/78923-prank-iz-videoigry-pererosshiy-v-realnuyu-strelbu-istoriya-gibeli-amerikanca-iz-za-sluchaynoy-ssory-v-call-of-duty'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 17},
#    'date': 1540728014,
#    'from_id': -28261334,
#    'id': 905538,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 183, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'Пранк из видеоигры, переросший в реальную стрельбу: история гибели американца из-за случайной ссоры ',
#     'share_url': 'https://tjournal.ru/78923-prank-iz-videoigry-pererosshiy-v-realnuyu-strelbu-istoriya-gibeli-amerikanca-iz-za-sluchaynoy-ssory-v-call-of-duty',
#     'type': 'share'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 17,
#    'reposts': {'count': 5, 'user_reposted': 0},
#    'text': 'Как часто люди угрожают друг другу в мультиплеерных видеоиграх? А как часто это приводит к реальным последствиям? Вот большой рассказ о том, как спор между игроками в Call of Duty стоил жизни отцу двоих детей.<br><br>Он никак не был связан с конфликтующими сторонами и просто попал на «линию огня».',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': '',
#       'image_big': 'https://pp.userapi.com/c845419/v845419572/1204c5/YEyU-MUcLY0.jpg',
#       'image_src': 'https://pp.userapi.com/c845419/v845419572/1204c3/eLY3M9eGHNE.jpg',
#       'target': 'internal',
#       'title': 'Московский дизайнер добился переименования столичного топонима. Правда, не до конца',
#       'url': 'https://tjournal.ru/78993-moskovskiy-dizayner-dobilsya-pereimenovaniya-stolichnogo-toponima-pravda-ne-do-konca'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 3},
#    'date': 1540724378,
#    'from_id': -28261334,
#    'id': 905525,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 94, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'Московский дизайнер добился переименования столичного топонима. Правда, не до конца',
#     'share_url': 'https://tjournal.ru/78993-moskovskiy-dizayner-dobilsya-pereimenovaniya-stolichnogo-toponima-pravda-ne-do-konca',
#     'type': 'share'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 3,
#    'reposts': {'count': 4, 'user_reposted': 0},
#    'text': 'Как парк Мосгордумы в центре Москвы превратился в парк Бове — и какое отношение к этому превращению имеет один столичный дизайнер.',
#    'to_id': -28261334},
#   {'attachments': [{'photo': {'access_key': '4890d8330538511656',
#       'aid': -7,
#       'created': 1540715377,
#       'height': 569,
#       'owner_id': -28261334,
#       'pid': 456248090,
#       'post_id': 905495,
#       'src': 'https://pp.userapi.com/c844720/v844720190/11bb34/h-oWFzB5NrU.jpg',
#       'src_big': 'https://pp.userapi.com/c844720/v844720190/11bb35/M-JdCikAIFc.jpg',
#       'src_small': 'https://pp.userapi.com/c844720/v844720190/11bb33/mgapK7bnoB0.jpg',
#       'src_xbig': 'https://pp.userapi.com/c844720/v844720190/11bb36/z50eel7UxDA.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c844720/v844720190/11bb37/RpqQY44CK-A.jpg',
#       'text': '',
#       'user_id': 100,
#       'width': 874},
#      'type': 'photo'}],
#    'comments': {'can_post': 1, 'count': 15},
#    'date': 1540720810,
#    'from_id': -28261334,
#    'id': 905495,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 992, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456248090,
#     'owner_id': -28261334,
#     'thumb_src': 'https://pp.userapi.com/c844720/v844720190/11bb34/h-oWFzB5NrU.jpg',
#     'type': 'photo'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 15,
#    'reposts': {'count': 9, 'user_reposted': 0},
#    'text': 'Хэллоуин: скоро (via iam_theforest)',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': 'Обычная ручка в космосе не работает, поэтому пришлось изобрести её заново.',
#       'image_big': 'https://pp.userapi.com/c846417/v846417862/117e24/-nwfl2CVRDM.jpg',
#       'image_src': 'https://pp.userapi.com/c846417/v846417862/117e22/aYqkRfdp72E.jpg',
#       'target': 'internal',
#       'title': 'Неэффективное NASA и находчивый СССР: как появился популярный миф о создании космической ручки и чем',
#       'url': 'https://tjournal.ru/78949-neeffektivnoe-nasa-i-nahodchivyy-sssr-kak-poyavilsya-populyarnyy-mif-o-sozdanii-kosmicheskoy-ruchki-i-chem-pishut-v-kosmose'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 19},
#    'date': 1540717214,
#    'from_id': -28261334,
#    'id': 905467,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 189, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'Неэффективное NASA и находчивый СССР: как появился популярный миф о создании космической ручки и чем',
#     'share_url': 'https://tjournal.ru/78949-neeffektivnoe-nasa-i-nahodchivyy-sssr-kak-poyavilsya-populyarnyy-mif-o-sozdanii-kosmicheskoy-ruchki-i-chem-pishut-v-kosmose',
#     'type': 'share'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 19,
#    'reposts': {'count': 6, 'user_reposted': 0},
#    'text': 'В 1960-х записать что-то в космосе было сложно. Обычная ручка в невесомости не работает, поэтому пришлось изобрести её заново.',
#    'to_id': -28261334},
#   {'attachments': [{'photo': {'access_key': '542e702cdde0f02392',
#       'aid': -7,
#       'created': 1540714551,
#       'height': 544,
#       'owner_id': -28261334,
#       'pid': 456248089,
#       'post_id': 905413,
#       'src': 'https://pp.userapi.com/c850724/v850724429/331f1/2cesK35qrhU.jpg',
#       'src_big': 'https://pp.userapi.com/c850724/v850724429/331f2/dNj7X3QXLJQ.jpg',
#       'src_small': 'https://pp.userapi.com/c850724/v850724429/331f0/hHudsfpPX_g.jpg',
#       'src_xbig': 'https://pp.userapi.com/c850724/v850724429/331f3/3zVVqOMPUCE.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c850724/v850724429/331f4/pLAVGTx8s4M.jpg',
#       'text': '',
#       'user_id': 100,
#       'width': 812},
#      'type': 'photo'}],
#    'comments': {'can_post': 1, 'count': 79},
#    'date': 1540714551,
#    'from_id': -28261334,
#    'id': 905413,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 83, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456248089,
#     'owner_id': -28261334,
#     'thumb_src': 'https://pp.userapi.com/c850724/v850724429/331f1/2cesK35qrhU.jpg',
#     'type': 'photo'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 79,
#    'reposts': {'count': 1, 'user_reposted': 0},
#    'text': 'Утро на TJ и обсуждаемые темы этих часов: <br><br>— Задержанному за нападение на синагогу в Питтсбурге предъявили обвинения по 29 пунктам https://tjournal.ru/78990<br><br>— Вертолёт владельца футбольного клуба «Лестер» разбился возле стадиона вскоре после матча https://tjournal.ru/78985<br><br>— Рогозин рассказал об успешном испытании беспилотного комбайна с искусственным интеллектом https://tjournal.ru/78989<br><br>На снимке: демонтаж памятника советским воинам в варшавском парке. Фото AP',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': 'В его коллекции есть снимки Чака Берри, Принса, Grateful Dead, U2 и других знаменитых музыкантов.',
#       'image_big': 'https://pp.userapi.com/c844617/v844617921/11b8b9/Sdfh3BcWkXE.jpg',
#       'image_src': 'https://pp.userapi.com/c844617/v844617921/11b8b7/1VXUEokByOs.jpg',
#       'target': 'internal',
#       'title': '«Съёмка запрещена»: фотограф несколько лет нелегально проносил камеру на концерты, куда не пускали ф',
#       'url': 'https://tjournal.ru/77140-semka-zapreshchena-fotograf-neskolko-let-nelegalno-pronosil-kameru-na-koncerty-kuda-ne-puskali-fotografov'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 8},
#    'date': 1540688401,
#    'from_id': -28261334,
#    'id': 905369,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 227, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': '«Съёмка запрещена»: фотограф несколько лет нелегально проносил камеру на концерты, куда не пускали ф',
#     'share_url': 'https://tjournal.ru/77140-semka-zapreshchena-fotograf-neskolko-let-nelegalno-pronosil-kameru-na-koncerty-kuda-ne-puskali-fotografov',
#     'type': 'share'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 8,
#    'reposts': {'count': 3, 'user_reposted': 0},
#    'text': 'В архиве американского фотографа свыше 10 тысяч концертных снимков самых известных исполнителей рок-н-ролла и рока, — но все они были сделаны нелегально.',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': 'Компания сперва извинилась, а потом удалила публикацию из соцсетей.',
#       'image_big': 'https://pp.userapi.com/c845019/v845019151/11f4ef/gx-m4JnA8e4.jpg',
#       'image_src': 'https://pp.userapi.com/c845019/v845019151/11f4ed/pLe2AhzNvKk.jpg',
#       'target': 'internal',
#       'title': 'IKEA обвинили в сексизме за пост про поцарапанную машину и погрызенные тапочки',
#       'url': 'https://tjournal.ru/78967'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 93},
#    'date': 1540681201,
#    'from_id': -28261334,
#    'id': 905276,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 123, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'IKEA обвинили в сексизме за пост про поцарапанную машину и погрызенные тапочки',
#     'share_url': 'https://tjournal.ru/78967',
#     'type': 'share'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 93,
#    'reposts': {'count': 4, 'user_reposted': 0},
#    'text': 'Главный скандал дня в рунете — с привкусом сексизма.',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': '',
#       'image_big': 'https://pp.userapi.com/c850224/v850224275/5adfd/gx_aND5QeyU.jpg',
#       'image_src': 'https://pp.userapi.com/c850224/v850224275/5adfb/CsPsQfFLvdA.jpg',
#       'target': 'internal',
#       'title': 'Вертолёт владельца футбольного клуба «Лестер» разбился возле стадиона вскоре после матча',
#       'url': 'https://tjournal.ru/78985-vertolet-vladelca-futbolnogo-kluba-lester-razbilsya-vozle-stadiona-vskore-posle-match'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 19},
#    'date': 1540679936,
#    'from_id': -28261334,
#    'id': 905259,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 67, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'Вертолёт владельца футбольного клуба «Лестер» разбился возле стадиона вскоре после матча',
#     'share_url': 'https://tjournal.ru/78985-vertolet-vladelca-futbolnogo-kluba-lester-razbilsya-vozle-stadiona-vskore-posle-match',
#     'type': 'share'},
#    'online': 0,
#    'post_source': {'type': 'api'},
#    'post_type': 'post',
#    'reply_count': 19,
#    'reposts': {'count': 1, 'user_reposted': 0},
#    'text': 'Вертолёт владельца «Лестера» упал возле стадиона вскоре после матча команды. <br><br>Неизвестно, был ли он сам в салоне и пострадал ли кто-то из болельщиков.',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': 'Поговорили с автором снимка, набирающего вирусную популярность в Твиттере.',
#       'image_big': 'https://pp.userapi.com/c849320/v849320873/a6c81/_O2TiPwXW7k.jpg',
#       'image_src': False,
#       'target': 'internal',
#       'title': 'Фото: «Матрица, которую мы заслужили»',
#       'url': 'https://tjournal.ru/78982-foto-matrica-kotoruyu-my-zasluzhili'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 12},
#    'date': 1540666807,
#    'from_id': -28261334,
#    'id': 905230,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 531, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'Фото: «Матрица, которую мы заслужили»',
#     'share_url': 'https://tjournal.ru/78982-foto-matrica-kotoruyu-my-zasluzhili',
#     'type': 'share'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 12,
#    'reposts': {'count': 14, 'user_reposted': 0},
#    'text': '«Матрица, которую мы заслужили»: нашли автора фотографии, которая сегодня завирусилась в соцсетях. <br><br>Он и не знал о растущей популярности своей работы, а снял её неподалёку от своего дома.',
#    'to_id': -28261334},
#   {'attachments': [{'photo': {'access_key': '943ec243381ecdc829',
#       'aid': -7,
#       'created': 1540630959,
#       'height': 256,
#       'owner_id': -28261334,
#       'pid': 456248054,
#       'post_id': 905186,
#       'src': 'https://pp.userapi.com/c845122/v845122663/117579/MDRjGmq1Tjk.jpg',
#       'src_big': 'https://pp.userapi.com/c845122/v845122663/11757a/8ZPR6DNMKZA.jpg',
#       'src_small': 'https://pp.userapi.com/c845122/v845122663/117578/_9zl1J_EZOw.jpg',
#       'text': '',
#       'user_id': 100,
#       'width': 477},
#      'type': 'photo'}],
#    'comments': {'can_post': 1, 'count': 20},
#    'date': 1540663210,
#    'from_id': -28261334,
#    'id': 905186,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 495, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456248054,
#     'owner_id': -28261334,
#     'thumb_src': 'https://pp.userapi.com/c845122/v845122663/117579/MDRjGmq1Tjk.jpg',
#     'type': 'photo'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 20,
#    'reposts': {'count': 13, 'user_reposted': 0},
#    'text': '',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': 'Это госучреждения и официальные процедуры. Рассказываю на примерах.',
#       'image_big': 'https://pp.userapi.com/c849232/v849232565/a55ad/la1im06LcMI.jpg',
#       'image_src': 'https://pp.userapi.com/c849232/v849232565/a55ab/zzNZ6i-i34I.jpg',
#       'target': 'internal',
#       'title': 'Что меня бесконечно удивляет в Польше',
#       'url': 'https://tjournal.ru/78794-chto-menya-beskonechno-udivlyaet-v-polshe'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 35},
#    'date': 1540659612,
#    'from_id': -28261334,
#    'id': 905154,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 339, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'Что меня бесконечно удивляет в Польше',
#     'share_url': 'https://tjournal.ru/78794-chto-menya-beskonechno-udivlyaet-v-polshe',
#     'type': 'share'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 35,
#    'reposts': {'count': 10, 'user_reposted': 0},
#    'text': 'Наш технический директор, некоторое время назад переехавший в Польшу, рассказывает, почему местные госучреждения и официальные процедуры не перестают его удивлять.',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': 'По неофициальным данным, погибли по меньшей мере четверо.',
#       'image_big': 'https://pp.userapi.com/c849024/v849024080/a8153/bh5sZgXwtQw.jpg',
#       'image_src': 'https://pp.userapi.com/c849024/v849024080/a8151/jRLzFvqNAWM.jpg',
#       'target': 'internal',
#       'title': 'В Питтсбурге мужчина устроил стрельбу в синагоге, есть погибшие',
#       'url': 'https://tjournal.ru/78978-v-pittsburge-muzhchina-ustroil-strelbu-v-sinagoge-est-pogibshie'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 20},
#    'date': 1540655113,
#    'from_id': -28261334,
#    'id': 905133,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 56, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'В Питтсбурге мужчина устроил стрельбу в синагоге, есть погибшие',
#     'share_url': 'https://tjournal.ru/78978-v-pittsburge-muzhchina-ustroil-strelbu-v-sinagoge-est-pogibshie',
#     'type': 'share'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 20,
#    'reposts': {'count': 3, 'user_reposted': 0},
#    'text': 'Мужчина, открывший стрельбу в синагоге в Питтсбурге, сдался полиции.',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': 'Погибли по меньшей мере четверо.',
#       'image_big': 'https://pp.userapi.com/c849532/v849532080/a3a05/QW2Dh-RQg9c.jpg',
#       'image_src': 'https://pp.userapi.com/c849532/v849532080/a3a03/bUANO6bu4ZQ.jpg',
#       'target': 'internal',
#       'title': 'В Питтсбурге неизвестный устроил стрельбу в синагоге, есть погибшие',
#       'url': 'https://tjournal.ru/78978-v-pittsburge-neizvestnyy-ustroil-strelbu-v-sinagoge-est-pogibshie'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 21},
#    'date': 1540652496,
#    'from_id': -28261334,
#    'id': 905095,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 59, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'В Питтсбурге неизвестный устроил стрельбу в синагоге, есть погибшие',
#     'share_url': 'https://tjournal.ru/78978-v-pittsburge-neizvestnyy-ustroil-strelbu-v-sinagoge-est-pogibshie',
#     'type': 'share'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 21,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': 'В Питтсбурге стрельба в синагоге, есть погибшие.',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': 'Но в пресс-службе канала заметили, что готовы рассмотреть её резюме.',
#       'image_big': 'https://pp.userapi.com/c845418/v845418565/11b3ff/AVUlaUAk9eI.jpg',
#       'image_src': 'https://pp.userapi.com/c845418/v845418565/11b3fd/l1WATY1k5FM.jpg',
#       'target': 'internal',
#       'title': 'Первый канал назвал иронией приглашение на работу американской журналистки, уволенной с NBC за расиз',
#       'url': 'https://tjournal.ru/78977-pervyy-kanal-nazval-ironiey-priglashenie-na-rabotu-amerikanskoy-zhurnalistki-uvolennoy-s-nbc-za-rasizm'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 18},
#    'date': 1540651579,
#    'from_id': -28261334,
#    'id': 905082,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 84, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'Первый канал назвал иронией приглашение на работу американской журналистки, уволенной с NBC за расиз',
#     'share_url': 'https://tjournal.ru/78977-pervyy-kanal-nazval-ironiey-priglashenie-na-rabotu-amerikanskoy-zhurnalistki-uvolennoy-s-nbc-za-rasizm',
#     'type': 'share'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 18,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': 'Вчера ведущий Первого канала позвал к себе в напарницы американскую журналистку Мегин Келли, уволенную за замечание, которое её начальство сочло расистским. Сегодня в пресс-службе канала заверили, что это была ирония. <br><br>Но заметили, что готовы рассмотреть её резюме.',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': '',
#       'image_big': 'https://pp.userapi.com/c852024/v852024390/30fef/od4Y4oMzPU0.jpg',
#       'image_src': 'https://pp.userapi.com/c852024/v852024390/30fed/bvtVBDbErpA.jpg',
#       'target': 'internal',
#       'title': '«Не нужно делать очередной ролик в новогоднем стиле»: агентства о лучших и худших идеях для празднич',
#       'url': 'https://vc.ru/marketing/49250-ne-nuzhno-delat-ocherednoy-rolik-v-novogodnem-stile-agentstva-o-luchshih-i-hudshih-ideyah-dlya-prazdnichnyh-kampaniy'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 7},
#    'date': 1540648813,
#    'from_id': -28261334,
#    'id': 905056,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 162, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': '«Не нужно делать очередной ролик в новогоднем стиле»: агентства о лучших и худших идеях для празднич',
#     'share_url': 'https://vc.ru/marketing/49250-ne-nuzhno-delat-ocherednoy-rolik-v-novogodnem-stile-agentstva-o-luchshih-i-hudshih-ideyah-dlya-prazdnichnyh-kampaniy',
#     'type': 'share'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 7,
#    'reposts': {'count': 6, 'user_reposted': 0},
#    'text': 'Специалисты рассказывают, как брендам подготовиться к наступлению праздничного сезона: какую рекламу можно взять за образец, а что делать не стоит.',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': 'В музее её покупать отказались, так как таких масок может быть несколько сотен.',
#       'image_big': 'https://pp.userapi.com/c851532/v851532419/304b5/IWyo_5kP9lY.jpg',
#       'image_src': 'https://pp.userapi.com/c851532/v851532419/304b3/DuYd7TbiSBA.jpg',
#       'target': 'internal',
#       'title': 'На Avito выставили на продажу посмертную маску Пушкина за 100 тысяч рублей',
#       'url': 'https://tjournal.ru/78971-na-avito-vystavili-na-prodazhu-posmertnuyu-masku-pushkina-za-100-tysyach-rubley'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 16},
#    'date': 1540645213,
#    'from_id': -28261334,
#    'id': 905011,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 145, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'На Avito выставили на продажу посмертную маску Пушкина за 100 тысяч рублей',
#     'share_url': 'https://tjournal.ru/78971-na-avito-vystavili-na-prodazhu-posmertnuyu-masku-pushkina-za-100-tysyach-rubley',
#     'type': 'share'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 16,
#    'reposts': {'count': 2, 'user_reposted': 0},
#    'text': 'На Avito продаётся посмертная маска Пушкина — это копия с оригинала, но всё равно достаточно раритетная вещь, передававшаяся в семье нынешнего владельца по наследству. <br><br>Правда, во Всероссийском музее Пушкина её купить отказались — у них целый шкаф копий.',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': '',
#       'image_big': 'https://pp.userapi.com/c851132/v851132390/31dcf/lqi_Gwv1Ut4.jpg',
#       'image_src': 'https://pp.userapi.com/c851132/v851132390/31dcd/5BoBCUt7c74.jpg',
#       'target': 'internal',
#       'title': 'Сторонник Трампа с криминальным прошлым: что известно о первом подозреваемом по делу о посылках с бо',
#       'url': 'https://tjournal.ru/78950'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 37},
#    'date': 1540640841,
#    'from_id': -28261334,
#    'id': 904930,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 66, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'Сторонник Трампа с криминальным прошлым: что известно о первом подозреваемом по делу о посылках с бо',
#     'share_url': 'https://tjournal.ru/78950',
#     'type': 'share'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 37,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': 'Собрали в одном месте всё, что на данный момент известно о мужчине, задержанном в США по подозрению в рассылке бомб. <br><br>Это американец без образования и дома, с финансовыми проблемами и нелюбовью к демократам.',
#    'to_id': -28261334},
#   {'attachments': [{'type': 'video',
#      'video': {'access_key': 'b80b937a0a45d7bee5',
#       'date': 1540637454,
#       'description': '',
#       'duration': 60,
#       'first_frame_1280': 'https://pp.userapi.com/c849332/v849332537/a1583/Llp4O6ZRb9I.jpg',
#       'first_frame_130': 'https://pp.userapi.com/c849332/v849332537/a1587/zq3mizh1gZc.jpg',
#       'first_frame_160': 'https://pp.userapi.com/c849332/v849332537/a1586/0vanPahxsg4.jpg',
#       'first_frame_320': 'https://pp.userapi.com/c849332/v849332537/a1585/ER5vDjrN08g.jpg',
#       'first_frame_800': 'https://pp.userapi.com/c849332/v849332537/a1584/JynIT2q0jlQ.jpg',
#       'image': 'https://pp.userapi.com/c851328/v851328710/2fe2a/Xb4a2RV_9cs.jpg',
#       'image_big': 'https://pp.userapi.com/c851328/v851328710/2fe2b/g99hJD6gBbk.jpg',
#       'image_small': 'https://pp.userapi.com/c851328/v851328710/2fe2c/W58Ly4eTAug.jpg',
#       'owner_id': -28261334,
#       'repeat': 1,
#       'title': 'В Стамбуле бездомная кошка взобралась на подиум (via hknylcn)',
#       'vid': 456239257,
#       'views': 104597}}],
# ...
#       'image_big': 'https://pp.userapi.com/c845121/v845121850/11d2c1/peJqyw6mWbI.jpg',
#       'image_src': 'https://pp.userapi.com/c845121/v845121850/11d2bf/GMJ726ch1tM.jpg',
#       'target': 'internal',
#       'title': 'Насилие, социальная инженерия и успех: как нигерийцы используют обряды и «магию» для интернет-мошенн',
#       'url': 'https://tjournal.ru/78813-nasilie-socialnaya-inzheneriya-i-uspeh-kak-nigeriycy-ispolzuyut-obryady-i-magiyu-dlya-internet-moshennichestva'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 16},
#    'date': 1540594801,
#    'from_id': -28261334,
#    'id': 904688,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 174, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'Насилие, социальная инженерия и успех: как нигерийцы используют обряды и «магию» для интернет-мошенн',
#     'share_url': 'https://tjournal.ru/78813-nasilie-socialnaya-inzheneriya-i-uspeh-kak-nigeriycy-ispolzuyut-obryady-i-magiyu-dlya-internet-moshennichestva',
#     'type': 'share'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 16,
#    'reposts': {'count': 9, 'user_reposted': 0},
#    'text': 'Может ли оккультизм сочетаться с интернет-мошенничеством? Как показывает опыт Нигерии, да, но весьма жёстким образом. В попытке украсть как можно больше денег у онлайн-жертв злоумышленники обращаются к ритуалам, надрезая себе руку, которой держат компьютерную мышь, или нападают на людей.<br><br>Судя по исследованиям, это логичный процесс — несмотря на век науки, оккультные традиции Нигерии закрепились в области киберпреступлений. Вот подробная история об этом явлении.',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': '',
#       'image_big': 'https://pp.userapi.com/c850424/v850424105/2fca7/vumzCk-fGR0.jpg',
#       'image_src': 'https://pp.userapi.com/c850424/v850424105/2fca5/8NhPFjv2zb8.jpg',
#       'target': 'internal',
#       'title': 'Американка жаловалась в поддержку Twitter на угрозы от подозреваемого в отправке бомб. Там ничего не',
#       'url': 'https://tjournal.ru/78955-amerikanka-zhalovalas-v-podderzhku-twitter-na-ugrozy-ot-podozrevaemogo-v-otpravke-bomb-tam-nichego-ne-sdelali'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 18},
#    'date': 1540591876,
#    'from_id': -28261334,
#    'id': 904669,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 109, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'Американка жаловалась в поддержку Twitter на угрозы от подозреваемого в отправке бомб. Там ничего не',
#     'share_url': 'https://tjournal.ru/78955-amerikanka-zhalovalas-v-podderzhku-twitter-na-ugrozy-ot-podozrevaemogo-v-otpravke-bomb-tam-nichego-ne-sdelali',
#     'type': 'share'},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 18,
#    'reposts': {'count': 1, 'user_reposted': 0},
#    'text': 'Подозреваемый в рассылке бомб, предположительно, вёл аккаунт в Твиттере с прямыми угрозами знаменитостям, к примеру, Джиму Керри. Присылал им жестокие фотографии и писал, что они скоро встретятся.<br><br>Но Twitter его не банил.',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': '',
#       'image_big': 'https://pp.userapi.com/c849124/v849124892/a7ea8/hX3yPvUot7k.jpg',
#       'image_src': 'https://pp.userapi.com/c849124/v849124892/a7ea6/RHAI6QdDA_k.jpg',
#       'target': 'internal',
#       'title': 'Сторонник Трампа с криминальным прошлым: что известно о первом подозреваемом по делу о посылках с бо',
#       'url': 'https://tjournal.ru/78950-storonnik-trampa-s-kriminalnym-proshlym-chto-izvestno-o-pervom-podozrevaemom-po-delu-o-posylkah-s-bombami'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 19},
#    'date': 1540583070,
#    'from_id': -28261334,
#    'id': 904637,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 65, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'Сторонник Трампа с криминальным прошлым: что известно о первом подозреваемом по делу о посылках с бо',
#     'share_url': 'https://tjournal.ru/78950-storonnik-trampa-s-kriminalnym-proshlym-chto-izvestno-o-pervom-podozrevaemom-po-delu-o-posylkah-s-bombami',
#     'type': 'share'},
#    'online': 0,
#    'post_source': {'type': 'api'},
#    'post_type': 'post',
#    'reply_count': 19,
#    'reposts': {'count': 2, 'user_reposted': 0},
#    'text': 'Первый подозреваемый по делу о посылках с бомбами для критиков Трампа ранее утверждал в судах, что работал кем угодно — от футболиста и танцора до борца и менеджера в стриптиз-клубе. На деле он был банкротом, живущим то ли с матерью, то ли в микроавтобусе.<br><br>К тому же он горячий сторонник нынешнего президента США: прошёл с ним немало митингов и критиковал демократов в соцсетях.',
#    'to_id': -28261334},
#   {'attachments': [{'photo': {'access_key': '824b8f6bbd17b6bba8',
#       'aid': -7,
#       'created': 1540555968,
#       'height': 208,
#       'owner_id': -28261334,
#       'pid': 456247990,
#       'post_id': 904612,
#       'src': 'https://pp.userapi.com/c851320/v851320597/2ecae/1FD0LVpfYo0.jpg',
#       'src_big': 'https://pp.userapi.com/c851320/v851320597/2ecaf/fXgXd2-S2N4.jpg',
#       'src_small': 'https://pp.userapi.com/c851320/v851320597/2ecad/FIcHI691xE8.jpg',
#       'text': '',
#       'user_id': 100,
#       'width': 479},
#      'type': 'photo'}],
#    'comments': {'can_post': 1, 'count': 20},
#    'date': 1540581159,
#    'from_id': -28261334,
#    'id': 904612,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 923, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456247990,
#     'owner_id': -28261334,
#     'thumb_src': 'https://pp.userapi.com/c851320/v851320597/2ecae/1FD0LVpfYo0.jpg',
#     'type': 'photo'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 20,
#    'reposts': {'count': 25, 'user_reposted': 0},
#    'text': '',
#    'to_id': -28261334},
#   {'attachments': [{'type': 'video',
#      'video': {'access_key': '06f8f5bc34f1ba579f',
#       'date': 1540578579,
#       'description': 'Производство видео — TJ',
#       'duration': 51,
#       'first_frame_1280': 'https://pp.userapi.com/c846120/v846120190/118004/GyQ3qw5d0BI.jpg',
#       'first_frame_130': 'https://pp.userapi.com/c846120/v846120190/118008/5ozk5Yvi43w.jpg',
#       'first_frame_160': 'https://pp.userapi.com/c846120/v846120190/118007/2ebs7AwG7Yw.jpg',
#       'first_frame_320': 'https://pp.userapi.com/c846120/v846120190/118006/iiytierhiCI.jpg',
#       'first_frame_800': 'https://pp.userapi.com/c846120/v846120190/118005/UYDdN0ol1gA.jpg',
#       'image': 'https://sun1-17.userapi.com/c831209/v831209190/1c86f6/15zx8LVYiFM.jpg',
#       'image_big': 'https://sun1-6.userapi.com/c831209/v831209190/1c86f7/C9ta0IMocPk.jpg',
#       'image_small': 'https://sun1-2.userapi.com/c831209/v831209190/1c86f8/PJguQJh6utc.jpg',
#       'owner_id': -28261334,
#       'title': 'Фестиваль тыкв в Нью-Йорке',
#       'vid': 456239256,
#       'views': 31320}}],
#    'comments': {'can_post': 1, 'count': 3},
#    'date': 1540579063,
#    'from_id': -28261334,
#    'id': 904596,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 203, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456239256, 'owner_id': -28261334, 'type': 'video'},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 3,
#    'reposts': {'count': 4, 'user_reposted': 0},
#    'text': 'Каждый год в нью-йоркском парке проходит знаменитый фестиваль тыкв — и 2018-й не стал исключением.<br><br>В этот раз организаторы использовали 7 тысяч тыкв для создания светильников, скульптур и инсталляций к Хэллоуину.',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': 'Поверившие журналисты даже позвонили ректору МФТИ за комментарием.',
#       'image_big': 'https://pp.userapi.com/c850016/v850016487/a032c/fCDD5BMF770.jpg',
#       'image_src': 'https://pp.userapi.com/c850016/v850016487/a032a/yFO9jRFCVcI.jpg',
#       'target': 'internal',
#       'title': '«Москва FM» сделала сюжет о подготовке инженеров Space X по советским учебникам. Это новость сатирического издания',
#       'url': 'https://tjournal.ru/78946-moskva-fm-sdelala-syuzhet-o-podgotovke-inzhenerov-space-x-po-sovetskim-uchebnikam-eto-novost-satiricheskogo-izdaniya'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 11},
#    'date': 1540575775,
#    'from_id': -28261334,
#    'id': 904576,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 222, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': '«Москва FM» сделала сюжет о подготовке инженеров Space X по советским учебникам. Это новость сатирического издания',
#     'share_url': 'https://tjournal.ru/78946-moskva-fm-sdelala-syuzhet-o-podgotovke-inzhenerov-space-x-po-sovetskim-uchebnikam-eto-novost-satiricheskogo-izdaniya',
#     'type': 'share'},
#    'online': 0,
#    'post_source': {'type': 'api'},
#    'post_type': 'post',
#    'reply_count': 11,
#    'reposts': {'count': 9, 'user_reposted': 0},
#    'text': 'Российские СМИ не в первый раз попадаются на фейковые новости сатирического издания, но тут особый случай: «Москва FM» всерьёз сделала целый видеосюжет и позвонила ректору МФТИ за комментарием.',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': 'Он нашёл как преимущества вроде «адекватной цены», так и неприятные сюрпризы — например, аккумулятора для подогрева в комплекте нет.',
#       'image_big': 'https://pp.userapi.com/c846019/v846019008/1136e3/O6gnlHveBa8.jpg',
#       'image_src': 'https://pp.userapi.com/c846019/v846019008/1136e1/dlZxcEED688.jpg',
#       'target': 'internal',
#       'title': '«При чём тут приставка „смарт“, я не понимаю»: россиянин заказал умную куртку Xiaomi и получил не то, что ожидал',
#       'url': 'https://tjournal.ru/78935-pri-chem-tut-pristavka-smart-ya-ne-ponimayu-rossiyanin-zakazal-umnuyu-kurtku-xiaomi-i-poluchil-ne-to-chto-ozhidal'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 18},
#    'date': 1540571645,
#    'from_id': -28261334,
#    'id': 904549,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 156, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': '«При чём тут приставка „смарт“, я не понимаю»: россиянин заказал умную куртку Xiaomi и получил не то, что ожидал',
#     'share_url': 'https://tjournal.ru/78935-pri-chem-tut-pristavka-smart-ya-ne-ponimayu-rossiyanin-zakazal-umnuyu-kurtku-xiaomi-i-poluchil-ne-to-chto-ozhidal',
#     'type': 'share'},
#    'online': 0,
#    'post_source': {'type': 'api'},
#    'post_type': 'post',
#    'reply_count': 18,
#    'reposts': {'count': 1, 'user_reposted': 0},
#    'text': 'Новая «умная» куртка Xiaomi в России пока не продаётся, но оценить, насколько реальность соответствует описанию, уже можно.<br><br>Живущий в Китае россиянин неожиданно для себя не нашёл в комплекте внешний аккумулятор для подогрева. А в лютые морозы в ней всё же может быть холодновато.',
#    'to_id': -28261334},
#   {'attachments': [{'type': 'video',
#      'video': {'access_key': 'b1e9dc89ae0fd21e96',
#       'date': 1540569516,
#       'description': 'Дикий Запад. Боль, пушки, предательства. Ведущие TJ открывают для себя новую игру от Rockstar.<br><br>Хочешь, чтобы твоё сообщение появилось в эфире? Тогда сюда: https://www.donationalerts.ru/r/niketas',
#       'duration': 7728,
#       'first_frame_130': 'https://pp.userapi.com/c845216/v845216216/11f160/CYs3V6UfjX8.jpg',
#       'first_frame_160': 'https://pp.userapi.com/c845216/v845216216/11f15f/3k2Sf9L9Rm8.jpg',
#       'first_frame_320': 'https://pp.userapi.com/c845216/v845216216/11f15e/21D9fv-jV-k.jpg',
#       'first_frame_800': 'https://pp.userapi.com/c845216/v845216216/11f15d/upa62J_Gq_k.jpg',
#       'image': 'https://pp.userapi.com/c850332/v850332938/5a4d2/swDS8txJPFg.jpg',
#       'image_big': 'https://pp.userapi.com/c850332/v850332938/5a4d3/5GhC_qvyYBM.jpg',
#       'image_small': 'https://pp.userapi.com/c850332/v850332938/5a4d4/OSb97IAZjtA.jpg',
#       'owner_id': -28261334,
#       'title': 'TJ играет: Red Dead Redemption 2',
#       'vid': 456239254,
#       'views': 73973}}],
#    'comments': {'can_post': 1, 'count': 34},
#    'date': 1540569660,
#    'from_id': -28261334,
#    'id': 904513,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 157, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456239254, 'owner_id': -28261334, 'type': 'video'},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 34,
#    'reposts': {'count': 4, 'user_reposted': 0},
#    'text': 'Впервые на всех мониторах страны — стрим от TJ.<br><br>Играем в самую ожидаемую игру этой осени, читаем комментарии и общаемся с подписчиками, принимаем донаты, возможно лажаем (мы в первый раз!) и надеемся на лучшее.',
#    'to_id': -28261334},
#   {'attachments': [{'link': {'description': 'Ему около 50 лет, его доставили на допрос.',
#       'image_big': 'https://pp.userapi.com/c846418/v846418216/11e84f/D_k-iqiIFeU.jpg',
#       'image_src': 'https://pp.userapi.com/c846418/v846418216/11e84d/BPwkQQ7jpPo.jpg',
#       'target': 'internal',
#       'title': 'Во Флориде арестовали подозреваемого, рассылавшего бомбы Обаме и Клинтонам',
#       'url': 'https://tjournal.ru/78939-vo-floride-arestovali-podozrevaemogo-rassylavshego-bomby-obame-i-klintonam'},
#      'type': 'link'}],
#    'comments': {'can_post': 1, 'count': 3},
#    'date': 1540567876,
#    'from_id': -28261334,
#    'id': 904502,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 91, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'share_title': 'Во Флориде арестовали подозреваемого, рассылавшего бомбы Обаме и Клинтонам',
#     'share_url': 'https://tjournal.ru/78939-vo-floride-arestovali-podozrevaemogo-rassylavshego-bomby-obame-i-klintonam',
#     'type': 'share'},
#    'online': 0,
#    'post_source': {'type': 'api'},
#    'post_type': 'post',
#    'reply_count': 3,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': 'Арестованному около 50 лет, его доставили на допрос. Его личные данные, как и мотивы его действий, пока неизвестны.',
#    'to_id': -28261334},
#   {'attachments': [{'type': 'video',
#      'video': {'access_key': '7c1c456b758c1f7e86',
#       'date': 1540566441,
#       'description': 'Спойлер: не очень просто.<br><br>Производство видео — TJ<br>Музыка: OST The Thing by Ennio Morricone',
#       'duration': 97,
#       'first_frame_1280': 'https://pp.userapi.com/c851536/v851536765/2edd7/mmVEx4_r-1o.jpg',
#       'first_frame_130': 'https://pp.userapi.com/c851536/v851536765/2edda/4TSfo2L_cL8.jpg',
#       'first_frame_160': 'https://pp.userapi.com/c851536/v851536765/2edd9/N9Wi9zpswBo.jpg',
#       'first_frame_320': 'https://pp.userapi.com/c851536/v851536765/2edd8/L45Ky8FXGUM.jpg',
#       'first_frame_800': 'https://pp.userapi.com/c851536/v851536765/2edd6/0g8HR3V2zDI.jpg',
#       'image': 'https://pp.userapi.com/c845520/v845520638/11b90a/OIWONDbnsyU.jpg',
#       'image_big': 'https://pp.userapi.com/c845520/v845520638/11b90b/zhMoklfIAqY.jpg',
#       'image_small': 'https://pp.userapi.com/c845520/v845520638/11b90c/n-_QM-WH8OA.jpg',
#       'owner_id': 62711547,
#       'title': 'Как проходит зима на Южном полюсе',
#       'vid': 456240022,
#       'views': 35814}}],
#    'comments': {'can_post': 1, 'count': 13},
#    'date': 1540566901,
#    'from_id': -28261334,
#    'id': 904495,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 387, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456240022, 'owner_id': 62711547, 'type': 'video'},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 13,
#    'reposts': {'count': 14, 'user_reposted': 0},
#    'text': 'Зима на Южном полюсе сильно отличается от обычной зимы: она длится полгода, во время которых учёные на антарктических станциях отрезаны от мира, а температура на улице опускается до -89 градусов.<br><br>Большую часть времени исследователи просто поддерживают работу станций и проходят через странные ритуалы — например, смотрят «Нечто» и выливают кипяток на мороз.',
#    'to_id': -28261334}]}

# %%
users = load_obj('final_data_user_only')
uids = [uid[0].get('uid') for uid in users]

# %%
print_counter = 0
final_data = []

for uid in uids[:1000]:
    try:
        user_subs = vk_get_response(
            'users.getSubscriptions', 'user_id={0}&v=4.9&lang=ru'.format(int(uid)), access_token
        )
        time.sleep(0.3)
        final_data.append(user_subs)
    except:
        print("Error")
    if print_counter % 100 == 0:
        print("{0} profiles done".format(print_counter))
    print_counter += 1
# Out:
# 0 profiles done
# 100 profiles done
# 200 profiles done
# 300 profiles done
# 400 profiles done
# 500 profiles done
# 600 profiles done
# 700 profiles done
# 800 profiles done
# 900 profiles done

# %%
subs_list = []
groups_freq_dict = {}
top_n = 5

for record, uid in zip(final_data, uids):
    try:
        user_subs = record
        if not user_subs.get('response'):
            user_subs = vk_get_response(
                'users.getSubscriptions', 'user_id={0}&v=4.9&lang=ru'.format(int(uid)), access_token
            )
        subs_pd = pd.DataFrame(
            [
                {
                    'groups_count': user_subs['response']['groups'].get('count'),
                    'groups_list': user_subs['response']['groups'].get('items'),
                    'follows_count':user_subs['response']['users'].get('count'),
                    'follows_list': user_subs['response']['users'].get('items'),
                }
            ]
        )

        for group_id in user_subs['response']['groups'].get('items')[:top_n]:
            if groups_freq_dict.get(group_id):
                groups_freq_dict[group_id] += 1
            else:
                groups_freq_dict[group_id] = 1

        subs_pd['subs_count'] = subs_pd['groups_count'] + subs_pd['follows_count']
        subs_list.append(subs_pd)
    except:
#         print(user_subs)
        pass
    if len(subs_list) % 100 == 0:
        print("Processed {0} users".format(len(subs_list)))
# Out:
# Processed 100 users
# Processed 200 users
# Processed 200 users
# Processed 300 users
# Processed 300 users
# Processed 400 users
# Processed 500 users
# Processed 600 users
# Processed 700 users
# Processed 800 users

# %%
sorted([(key, val) for key, val in groups_freq_dict.items()], key=lambda x: x[1], reverse=True)[:5]
# Out:
# [(84354128, 51),
#  (57846937, 33),
#  (29246653, 32),
#  (40498005, 30),
#  (28528027, 25)]

# %%
group_doc_dict = {}
counter = 0
groups_freq_dict_top5 = groups_freq_dict

for group_id, freq in groups_freq_dict_top5.items():
    counter += 1
    try:
        check = vk_get_response(
            'wall.get',
            'owner_id={0}&count=100&fields=post_type,marked_as_ads&&v=4.9&lang=ru'.format(int(group_id) * -1),
            access_token_3
        )
        check = check['response']
        group_doc = ''
        if check[0] != 0:
            for post in check[1:]:
                if post.get('marked_as_ads') != 1:
                    group_doc += post['text']
        group_doc_dict[group_id] = group_doc
    except:
        print("Response error. Group id {0}".format(group_id))
        print(check)
    if counter % 100 == 0:
        print("{0} groups extracted".format(counter))
    time.sleep(0.3)
# Out:
# 100 groups extracted
# 200 groups extracted
# 300 groups extracted
# 400 groups extracted
# 500 groups extracted
# 600 groups extracted
# 700 groups extracted
# 800 groups extracted
# 900 groups extracted
# 1000 groups extracted
# 1100 groups extracted
# 1200 groups extracted
# 1300 groups extracted
# 1400 groups extracted
# 1500 groups extracted
# 1600 groups extracted
# 1700 groups extracted
# 1800 groups extracted
# 1900 groups extracted
# 2000 groups extracted
# 2100 groups extracted
# 2200 groups extracted
# 2300 groups extracted

# %%
save_obj(group_doc_dict, 'group_doc_dict')

# %%
from bs4 import BeautifulSoup
import re
import string
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import nltk
from pymorphy2 import MorphAnalyzer

# %%
chrs_to_delete = string.punctuation + u'»' + u'«' + u'—' + u'“' + u'„' + u'•' + u'#'
translation_table = {ord(c): None for c in chrs_to_delete if c != u'-'}
units = MorphAnalyzer.DEFAULT_UNITS
morph = MorphAnalyzer(result_type=None, units=units)
PortSt = PorterStemmer()
stopw = set(
    [w for w in stopwords.words(['russian', 'english'])]
    + [u'это', u'году', u'года', u'также', u'етот',
       u'которые', u'который', u'которая', u'поэтому',
       u'весь', u'свой', u'мочь', u'eтот', u'например',
       u'какой-то', u'кто-то', u'самый', u'очень', u'несколько',
       u'источник', u'стать', u'время', u'пока', u'однако',
       u'около', u'немного', u'кроме', u'гораздо', u'каждый',
       u'первый', u'вполне', u'из-за', u'из-под',
       u'второй', u'нужно', u'нужный', u'просто', u'большой',
       u'хороший', u'хотеть', u'начать', u'должный', u'новый', u'день',
       u'метр', u'получить', u'далее', u'именно', u'апрель',
       u'сообщать', u'разный', u'говорить', u'делать',
       u'появиться', u'2016',
       u'2015', u'получить', u'иметь', u'составить', u'дать', u'читать',
       u'ничто', u'достаточно', u'использовать',
       u'принять', u'практически',
       u'находиться', u'месяц', u'достаточно', u'что-то', u'часто',
       u'хотеть', u'начаться', u'делать', u'событие', u'составлять',
       u'остаться', u'заявить', u'сделать', u'дело',
       u'примерно', u'попасть', u'хотя', u'лишь', u'первое',
       u'больший', u'решить', u'число', u'идти', u'давать', u'вопрос',
       u'сегодня', u'часть', u'высокий', u'главный', u'случай', u'место',
       u'конец', u'работать', u'работа', u'слово', u'важный', u'сказать']
)

# %%
url_start = 'http[s]?://'
url_end = (
    '(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
)
pattern = url_start + url_end

# %%
group_clean_doc_dict = {}
counter = 0

for group_id, doc in group_doc_dict.items():
    soup = BeautifulSoup(doc, 'html.parser')
    body = ' '.join(
        [tag.string.replace('\\n', ' ').replace('\\r', ' ')
         for tag in soup.descendants if tag.string]
    )
    body = re.sub('\[.*?\]','', body)
    body = re.sub(pattern,'', body)
    if body != '':
        body_clean = body.translate(translation_table).lower().strip()
        words = word_tokenize(body_clean)
        tokens = []
        # stemming and text normalization
        for word in words:
            if re.match('^[a-z0-9-]+$', word) is not None:
                tokens.append(PortSt.stem(word))
            elif word.count('-') > 1:
                tokens.append(word)
            else:
                normal_forms = morph.normal_forms(word)
                tokens.append(normal_forms[0] if normal_forms else word)
        # remove stopwords and leave unique words only
        tokens = filter(
            lambda token: token not in stopw, sorted(set(tokens))
        )

        # remove all words with more than 3 chars
        tokens = filter(lambda token: len(token) > 3, tokens)
    else:
        tokens = []
    counter += 1
    if counter % 100 == 0:
        print("{0} docs processed".format(counter))
    group_clean_doc_dict[group_id] = tokens
# Out:
# 100 docs processed
# 200 docs processed
# 300 docs processed
# 400 docs processed
# 500 docs processed
# 600 docs processed
# 700 docs processed
# 800 docs processed
# 900 docs processed
# 1000 docs processed
# 1100 docs processed
# 1200 docs processed
# 1300 docs processed
# 1400 docs processed
# 1500 docs processed
# 1600 docs processed
# 1700 docs processed
# 1800 docs processed
# 1900 docs processed
# 2000 docs processed
# 2100 docs processed
# 2200 docs processed
# 2300 docs processed

# %%
group_clean_doc_dict = {key: list(val) for key, val in group_clean_doc_dict.items()}

# %%
save_obj(group_clean_doc_dict, 'group_doc_dict_clean')

# %%
group_clean_doc_dict = load_obj('group_doc_dict_clean')

# %%
from gensim.corpora import TextCorpus
from gensim.models.ldamulticore import LdaMulticore
from gensim.models.ldamodel import LdaModel

class ListTextCorpus(TextCorpus):

    def get_texts(self):
        for doc in self.input:
            yield doc
                
mycorp = ListTextCorpus(input=group_clean_doc_dict.values())
justlda = LdaModel(
    corpus=mycorp, num_topics=20, passes=12
)

# %%
print('LdaModel performance')
for i in range(20):
    terms = justlda.get_topic_terms(i)
    print(i, ' '.join(map(lambda x: mycorp.dictionary.get(x[0]), terms)))
# Out:
# LdaModel performance
# 0 человек жизнь знать твой никто видеть хотеться почему глаз пожалуйста
# 1 ребёнок жизнь ждать сохранить человек красивый судьба твой друг любовь
# 2 друг конора рука победить макгрегор тренировка хабиб боец нурмагомед конором
# 3 dark rock roll идея night blue фото music следующий time
# 4 человек жить любовь 2018 возpаста невoзмoжнo жpaть ждать утро внешность
# 5 игрок матч лига пенальти состав победа серия клуб футболист выиграть
# 6 октябрь ждать игра коммент приходить крутой пройти друг любимый последний
# 7 человек жизнь друг группа фото смотреть видеть любимый момент клип
# 8 человек жизнь друг знать жить любить ждать видеть смотреть найти
# 9 цена капот кузов music нибыть продажа фильтр привод фара колодка
# 10 выглядеть милый любить человек писать друг красивый стиль настроение акция
# 11 человек жизнь друг знать ждать думать смотреть найти любить смочь
# 12 салат рецепт ингредиент вкусный яйцо куриный блюдо соль вкусно соус
# 13 кататься шлем индивидуальный вчера жизнь группа включение соревнование show проходить
# 14 человек помощь ребёнок друг знать ждать жизнь телефон рубль россия
# 15 чтoб жизнь тoлькo кoгдa тeбить дeнь этoт ecть мeнить oдин
# 16 размер отличный кожа любой сантиметр форма помочь цвета люба цвет
# 17 район московский москва территория житель центр 2018 площадь станция октябрь
# 18 смотреть папа любимый красота понимать пара момент 2018 съёмка возраст
# 19 жуткo oчередь глупo пеpемена вoзьмитя кем-тo oшибoк нeскoлькo нeмнoгo дeржать

# %%
dummy_dict = {key: 0 for key in range(20)}

group_topics_dict_20 = {
    group_id: dict(list(dummy_dict.items()) + justlda.get_document_topics(mycorp.dictionary.doc2bow(text)))
    for group_id, text in group_clean_doc_dict.items()
}
check_pd_20 = pd.DataFrame.from_dict(group_topics_dict_20, orient='index')
check_pd_20.head(10)
print("Group distribution by the most relevant topic")
pd.Series.round(check_pd_20.idxmax(axis=1).value_counts() * 1. / len(check_pd_20), 2)
# Out:
# Group distribution by the most relevant topic
# 11    0.51
# 16    0.08
# 17    0.06
# 8     0.06
# 0     0.04
# 12    0.04
# 14    0.03
# 7     0.02
# 15    0.02
# 3     0.01
# 2     0.01
# 10    0.01
# 5     0.01
# 4     0.01
# 18    0.01
# 1     0.01
# 6     0.01
# 13    0.01
# 9     0.01
# 19    0.01
# dtype: float64

# %%
# dump lda model to disk
justlda.save('ldamodel_20_topics')

# %%
print("The most typical groups for every topic")
for i in range(20):
    terms = justlda.get_topic_terms(i)
    print(i, ' '.join(map(lambda x: mycorp.dictionary.get(x[0]), terms)))
    typical_groups = check_pd_20[i].sort_values(ascending=False).index[:10]
    for g in typical_groups:
        group_info = vk_get_response(
            'groups.getById', 'group_ids={0}&v=4.9&lang=ru'.format(g), access_token
        )
        print(group_info['response'][0]['name'] + ' ' + 'http://vk.com/club' + str(g))
        time.sleep(0.3)
    print()
# Out:
# The most typical groups for every topic
# 0 человек жизнь знать твой никто видеть хотеться почему глаз пожалуйста
# Гречневая Кафка http://vk.com/club69864801
# Юмор Шрёдингера http://vk.com/club58737741
# 最も好きな写真 http://vk.com/club2629371
# LUXURIOUS LIFE ™ http://vk.com/club39748345
# Гриффиндор | Рик и Морти | Симпсоны http://vk.com/club88674651
# MEN'S GROUP http://vk.com/club39765355
# Иллюзионист http://vk.com/club127090395
# Практическая психология http://vk.com/club41538339
# MMOBoom.ru http://vk.com/club48007933
# ГАРАЖ | GARAGE http://vk.com/club74297965
#
# 1 ребёнок жизнь ждать сохранить человек красивый судьба твой друг любовь
# Мужчина должен быть... http://vk.com/club36719060
# Киномания Кино театр  Москва http://vk.com/club50571799
# Школа кулинарии | Вкусные рецепты http://vk.com/club49694199
# Здоровые дети - тут все о семье, маме, малыше http://vk.com/club50059253
# Дрифт http://vk.com/club58168203
# Малогабаритка http://vk.com/club141409293
# E S Q U I R E http://vk.com/club64434153
# Men's Job | MJB http://vk.com/club137585081
# Своими Руками | Так Просто http://vk.com/club149499405
# Путешествия http://vk.com/club38363244
#
# 2 друг конора рука победить макгрегор тренировка хабиб боец нурмагомед конором
# Low &amp; Slow http://vk.com/club30145860
# IT'S TIME UFC http://vk.com/club50905357
# UFC | Жизнь бойца http://vk.com/club129386072
# Тупокайф! http://vk.com/club25201845
# Дерзкая Княгиня http://vk.com/club153202636
# Fashion - мода и стиль http://vk.com/club28646177
# AMOUR (ЦВЕТЫ, ГЕЛИЕВЫЕ ШАРЫ) /КЕМЕРОВО http://vk.com/club126974657
# Travelerr.ru - дешевые путешествия http://vk.com/club41053835
# Территория фактов http://vk.com/club119032732
# Уроки Красоты | Маникюр | Прически | Макияж http://vk.com/club25171514
#
# 3 dark rock roll идея night blue фото music следующий time
# Мода http://vk.com/club39043096
# Интересно жить на свете http://vk.com/club95855125
# Другая Музыка http://vk.com/club35486626
# Imaginary World http://vk.com/club31706120
# ГОРЯЧО http://vk.com/club28693127
# CRASH - блог об электронной музыке http://vk.com/club29013286
# Жесть, какая татуировка! http://vk.com/club16348810
# Архив эскизов для тату. http://vk.com/club101972843
# SOVI http://vk.com/club156635265
# Boris Brejcha http://vk.com/club23487223
#
# 4 человек жить любовь 2018 возpаста невoзмoжнo жpaть ждать утро внешность
# MOUNTAIN MAN http://vk.com/club69669211
# Cosy Hearth http://vk.com/club79320083
# USA. США. Английский язык - Всё об Америке http://vk.com/club22558194
# Тату и эскизы http://vk.com/club25749497
# Travel Corporation - путешествия, туризм http://vk.com/club128067772
# Интеллектуальный юмор http://vk.com/club28950133
# Литературная беседка http://vk.com/club45023794
# Кто бы мог подумать! http://vk.com/club79788640
# Перфекционист http://vk.com/club90480377
# Новинки Музыки 2018 http://vk.com/club31501328
#
# 5 игрок матч лига пенальти состав победа серия клуб футболист выиграть
# Fairwind http://vk.com/club136119979
# Мировой Футбол http://vk.com/club4290276
# Tokio Hotel http://vk.com/club23064248
# ФК "Бавария" Мюнхен / FC Bayern München http://vk.com/club60079200
# VISUAL COCAINE http://vk.com/club31545235
# Немношк Художник | Бот http://vk.com/club56255356
# Betraveler | Добро пожаловать на Землю http://vk.com/club26127512
# ЭТУ СТРАНУ НЕ ПОБЕДИТЬ!!! http://vk.com/club36200261
# Авто Винил Бирюлево Восточное http://vk.com/club172219194
# Футбол Европы: АПЛ, РПЛ, Ла Лига, Серия А http://vk.com/club23693281
#
# 6 октябрь ждать игра коммент приходить крутой пройти друг любимый последний
# Таня Ву http://vk.com/club135477738
# Dota 2. Artifact http://vk.com/club15413538
# Школа ремонта http://vk.com/club148199559
# Nvuti http://vk.com/club161045809
# ART BOX http://vk.com/club55623462
# Чёрный юмор http://vk.com/club40835481
# Клубная музыка 2018 http://vk.com/club28976701
# Travelling | Путешествия http://vk.com/club56978134
# Необычный гороскоп http://vk.com/club68481433
# КОМИКСЫ http://vk.com/club74382159
#
# 7 человек жизнь друг группа фото смотреть видеть любимый момент клип
# KARA SEVDA / БЕСКОНЕЧНАЯ  (ЧЁРНАЯ) ЛЮБОВЬ http://vk.com/club99351837
# Авторынок Волгоград №1 http://vk.com/club95475255
# Running Man | 런닝맨 http://vk.com/club36844954
# Love  Radio http://vk.com/club17309915
# • Анекдоты http://vk.com/club35930308
# Шоумания - новости о звездах http://vk.com/club132564166
# ELIMI BIRAKMA/ НЕ ОТПУСКАЙ МОЮ РУКУ / FHVK http://vk.com/club129771930
# Прояснилось. http://vk.com/club27932995
# ~ oldschool fashion house http://vk.com/club114303353
# it felt so crystal in the air http://vk.com/club49003220
#
# 8 человек жизнь друг знать жить любить ждать видеть смотреть найти
# Психология ★ Эзотерика. Успех ★ Счастье http://vk.com/club58916750
# Женские  Хитрости http://vk.com/club31727306
# 1000 и 1 ФОТОПРИКОЛ http://vk.com/club352552
# Потеряха.Барнаул. Пропавшие/найденные животные. http://vk.com/club29426442
# МЫ ГОРЦЫ http://vk.com/club24682596
# • Неприличные Анекдоты http://vk.com/club28878216
# Интересно знать | Наука и факты http://vk.com/club78622646
# Гороскоп http://vk.com/club25379190
# 69 % пошлости http://vk.com/club95287151
# Женский Журнал Joy miss http://vk.com/club59879783
#
# 9 цена капот кузов music нибыть продажа фильтр привод фара колодка
# FREETEAM - Бесплатные Минуса / Биты http://vk.com/club14537087
# mikhaylovskaya plenka http://vk.com/club88256483
# BimmerSales http://vk.com/club50428280
# Гифки и интересные факты Вконтакте http://vk.com/club30371336
# Animart - милые аниме арты :3 http://vk.com/club45739204
# Моя квартира. Санкт-Петербург http://vk.com/club127925061
# Тысяча чертей, какая татуировка! http://vk.com/club26776509
# Диски WORLDWHEELS http://vk.com/club111846547
# ДИЗАЙН ИНТЕРЬЕРА  Спальни|Кухни|Ванной|Гостиной http://vk.com/club59301588
# ART LEGALE http://vk.com/club40485321
#
# 10 выглядеть милый любить человек писать друг красивый стиль настроение акция
# Academic Architecture http://vk.com/club77988045
# Ищу модель Москва http://vk.com/club167075082
# Ключи для Доктор Веб (Dr.Web) на 2018 год http://vk.com/club16776762
# 1000 фактов http://vk.com/club48338388
# S W A G http://vk.com/club32515782
# Сарказм http://vk.com/club60801114
# Top-Notch English Английский язык http://vk.com/club115061412
# FASHION  мода http://vk.com/club33404310
# M O D A http://vk.com/club34351337
# Абстракция | GIF http://vk.com/club152328692
#
# 11 человек жизнь друг знать ждать думать смотреть найти любить смочь
# Агентство интернет-рекламы - Таргет без купюр http://vk.com/club112634825
# Zaymigo - мгновенные онлайн займы http://vk.com/club72115470
# Телец http://vk.com/club162456827
# Великие Слова | Цитаты и Афоризмы http://vk.com/club23170931
# Как заработать денег? http://vk.com/club73260851
# Бизнес-журнал «Shark» http://vk.com/club94917592
# Факты о родившихся 24 апреля http://vk.com/club135537052
# Факты о родившихся 24 августа http://vk.com/club128280451
# КиноКайф - лучшее из мира кино! http://vk.com/club34199707
# Анна Богаец|Как начать бизнес с нуля в интернете http://vk.com/club167104441
#
# 12 салат рецепт ингредиент вкусный яйцо куриный блюдо соль вкусно соус
# Первый Вегетарианский http://vk.com/club58656979
# GIF Рецепты http://vk.com/club152707004
# ●ВКУСНЯШКА● Кулинария. Рецепты. http://vk.com/club68576320
# Готовим Сами http://vk.com/club153008189
# Коллекция Рецептов http://vk.com/club35806378
# Готовим детям. Рецепты мамам. Кулинария. Меню http://vk.com/club50294423
# Приятного аппетита http://vk.com/club31494747
# Рецепты от шефа. Кулинария http://vk.com/club3162791
# Детское питание/ Меню • Рецепты для детей http://vk.com/club106970447
# ▲Выжить на сотку▲ http://vk.com/club152160690
#
# 13 кататься шлем индивидуальный вчера жизнь группа включение соревнование show проходить
# Mercedes-Benz Society http://vk.com/club28317077
# MUZ.BOOM http://vk.com/club131088386
# Современное искусство http://vk.com/club35486596
# 90's lovers http://vk.com/club41088245
# AUTO GID http://vk.com/club163406855
# Болеем за наших! http://vk.com/club57893352
# Дизайн интерьера http://vk.com/club33301261
# Идеи для дома - Дизайн интерьера http://vk.com/club49290489
# Территория уюта http://vk.com/club161056503
# ГЛЯНЕЦ • женский журнал http://vk.com/club49973899
#
# 14 человек помощь ребёнок друг знать ждать жизнь телефон рубль россия
# Дом 2 http://vk.com/club35244547
# Игрофаны без тормозов •  Супер Стримеры http://vk.com/club116931591
# Помощь Ирине Пироговой http://vk.com/club172862872
# Невероятная история http://vk.com/club53616464
# Вселенная MARVEL|DC http://vk.com/club112940897
# Ищу модель Москва http://vk.com/club164682776
# Новости Саранск | Мордовия «Столица С» http://vk.com/club38801259
# videosos http://vk.com/club56263398
# Спортсмен http://vk.com/club137624961
# EMPIRE | История Человечества http://vk.com/club61134563
#
# 15 чтoб жизнь тoлькo кoгдa тeбить дeнь этoт ecть мeнить oдин
# У каждого своя история http://vk.com/club23834959
# ФИЛЬМЫ УЖАСОВ http://vk.com/club30823579
# Бизнес секреты http://vk.com/club43037456
# Все лгут http://vk.com/club16598458
# These Magic Moments http://vk.com/club101240674
# ЯЖЛЕДИ! http://vk.com/club24260227
# Дневник Богини http://vk.com/club26717401
# Видео http://vk.com/club26090596
# ► Женские мысли и чувства http://vk.com/club108862336
# История|History http://vk.com/club53782768
#
# 16 размер отличный кожа любой сантиметр форма помочь цвета люба цвет
# TrandyHall Шоу рум Одежда В наличии и на заказ http://vk.com/club47746606
# Слова Великих людей http://vk.com/club28981879
# Саморазвитие http://vk.com/club38182092
# Мысли делают нас http://vk.com/club39265861
# Audi|Ауди http://vk.com/club56513920
# Дизайн Интерьера | 33 кв. метра http://vk.com/club153272708
# Детская одежда Nano |Канада| http://vk.com/club29913888
# Маникюр 2018. Идеи дизайна ногтей http://vk.com/club48223187
# Фильмы http://vk.com/club40335272
# АВТО http://vk.com/club90060110
#
# 17 район московский москва территория житель центр 2018 площадь станция октябрь
# Москва: Афиша бесплатных событий http://vk.com/club109198561
# 2do2go: Москва http://vk.com/club38415798
# Уютный декор для дома. Handmade и рукоделие http://vk.com/club28587219
# Мужские мысли http://vk.com/club25397178
# ДЕДОВСК - НАВСЕГДА http://vk.com/club454050
# Библиотека Бодибилдинга http://vk.com/club32343761
# Зубцов СМИ "NewMedia" http://vk.com/club109445285
# Дизайн Ногтей 2018 http://vk.com/club135977787
# PRO FOTO http://vk.com/club34084756
# Российская империя : все факты и история. http://vk.com/club44693766
#
# 18 смотреть папа любимый красота понимать пара момент 2018 съёмка возраст
# ЛОКОТЬ-INFO (другая сторона) http://vk.com/club168862527
# Гнездышко l Домашний уют, декор, дизайн http://vk.com/club71443542
# TOP-MODELS http://vk.com/club35521173
# Wonders of the World | Путешествия http://vk.com/club23964485
# СЕРИАЛЫ | Американская история ужасов http://vk.com/club27282322
# Счастливые родители http://vk.com/club48220724
# Las Vegas http://vk.com/club34607647
# MAD http://vk.com/club135162806
# Наука и Факты http://vk.com/club34118551
# Music Next Door http://vk.com/club16120134
#
# 19 жуткo oчередь глупo пеpемена вoзьмитя кем-тo oшибoк нeскoлькo нeмнoгo дeржать
# LOOK AT ME http://vk.com/club51888238
# Маникюр | Макияж | Фото-уроки http://vk.com/club64623755
# Мода 2018 | Прически | Макияж | Маникюр http://vk.com/club38737497
# А знаешь ли ты?! | Интересные факты http://vk.com/club82494292
# Интересная планета - путешествия и туризм http://vk.com/club27041765
#  http://vk.com/club33788217
# Вовсе не смешно http://vk.com/club26684698
# Привет, сейчас http://vk.com/club70120205
# Клуб красоты http://vk.com/club111718726
# BrainUP | Саморазвитие http://vk.com/club70427221

# %%
from operator import add

def groups_to_topics_v1(groups_list, n=5):
    counter = 1
    probs_sum = dummy_dict.values()
    for group_id in groups_list:
        topics_dict = group_topics_dict_20.get(group_id)
        rel_topic_probs = map(
            lambda x: x * (min(5, n) - counter + 1),
            dummy_dict.values() if not topics_dict else topics_dict.values()
        )
        probs_sum = map(add, probs_sum, rel_topic_probs)
        if counter == 5:
            break
        counter += 1
    return map(lambda x: x / sum([x + 1 for x in range(counter)]), probs_sum)

def groups_to_topics_v2(groups_list, n=5):
    counter = 1
    probs_sum = dummy_dict.values()
    for group_id in groups_list:
        topics_dict = group_topics_dict_20.get(group_id)
        rel_topic_probs = map(
            lambda x: x * 1,
            dummy_dict.values() if not topics_dict else topics_dict.values()
        )
        probs_sum = map(add, probs_sum, rel_topic_probs)
        if counter == 5:
            break
        counter += 1
    return map(lambda x: x, probs_sum)

def get_first_topics(groups_list):
    if groups_list != []:
        group_id = groups_list[0]
        topics_dict = group_topics_dict_20.get(group_id)
    else:
        topics_dict = dummy_dict
    return dummy_dict.values() if not topics_dict else topics_dict.values()

def get_main_interest(topic_probs):
    return np.argmax(topic_probs)
