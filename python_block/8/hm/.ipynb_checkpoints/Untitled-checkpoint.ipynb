# %%
from __future__ import (absolute_import, division,
                        print_function, unicode_literals)
# отключим предупреждения Anaconda
import warnings
warnings.simplefilter('ignore')

# будем отображать графики прямо в jupyter'e
# %pylab inline
#графики в svg выглядят более четкими
# %config InlineBackend.figure_format = 'svg' 

#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 11,9
import pandas as pd
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Предварительаня обработка данных

# %%
df = pd.read_csv('tmdb_5000_movies.csv', parse_dates = ['release_date'])

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
df.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500

# %%
def mk_dfrm_from_dict_col(dataframe, col_dict_name, *columns):
    '''Делает новый датафрейм из столбца датафрейма типа объект'''
    src_lst = []
    for index, cols in dataframe.iterrows():
        for d_row in eval(cols[col_dict_name]):
            col_n = [d_row[x] for x in  columns]
            src_lst.append((index, *col_n))
    return pd.DataFrame(src_lst)

# %%
tags = mk_dfrm_from_dict_col(df, 'keywords', 'id','name')
tags.columns ='movieid', 'tag_id', 'name_tag'

# %%
tags.head()
# Out:
#    movieid  tag_id       name_tag
# 0        0    1463  culture clash
# 1        0    2964         future
# 2        0    3386      space war
# 3        0    3388   space colony
# 4        0    3679        society

# %%
prod_comp = mk_dfrm_from_dict_col(df, 'production_companies', 'id','name')
prod_comp.columns ='movieid', 'comp_id', 'name_comp'
prod_comp.head()
# Out:
#    movieid  comp_id                               name_comp
# 0        0      289                 Ingenious Film Partners
# 1        0      306  Twentieth Century Fox Film Corporation
# 2        0      444                      Dune Entertainment
# 3        0      574                Lightstorm Entertainment
# 4        1        2                    Walt Disney Pictures

# %%
prod_country = mk_dfrm_from_dict_col(df, 'production_countries', 'iso_3166_1','name')
prod_country.columns ='movieid', 'iso_3166_1', 'name_country'
prod_country.head()
# Out:
#    movieid iso_3166_1              name_country
# 0        0         US  United States of America
# 1        0         GB            United Kingdom
# 2        1         US  United States of America
# 3        2         GB            United Kingdom
# 4        2         US  United States of America

# %%
genres = mk_dfrm_from_dict_col(df, 'genres', 'id','name')
genres.columns = 'movieid', 'id', 'genre'
genres.head()
# Out:
#    movieid   id            genre
# 0        0   28           Action
# 1        0   12        Adventure
# 2        0   14          Fantasy
# 3        0  878  Science Fiction
# 4        1   12        Adventure

# %%
languages = mk_dfrm_from_dict_col(df, 'spoken_languages', 'iso_639_1','name')
languages.columns = 'movieid', 'iso_639_1', 'name_'
languages.head()
# Out:
#    movieid iso_639_1     name_
# 0        0        en   English
# 1        0        es   Español
# 2        1        en   English
# 3        2        fr  Français
# 4        2        en   English

# %%
df = df.drop(['keywords','production_companies','production_countries','genres','spoken_languages'], axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 15 columns):
# budget               4803 non-null int64
# homepage             1712 non-null object
# id                   4803 non-null int64
# original_language    4803 non-null object
# original_title       4803 non-null object
# overview             4800 non-null object
# popularity           4803 non-null float64
# release_date         4802 non-null datetime64[ns]
# revenue              4803 non-null int64
# runtime              4801 non-null float64
# status               4803 non-null object
# tagline              3959 non-null object
# title                4803 non-null object
# vote_average         4803 non-null float64
# vote_count           4803 non-null int64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(7)
# memory usage: 562.9+ KB

# %%
df.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# max       10.000000  13752.000000

# %%
print(df.shape)
# Out:
# (4803, 15)

# %%
values_to_fill = {'homepage' : '','tagline' : ''}
df = df.fillna(value = values_to_fill)

# %%
df['release_date'] = pd.to_datetime(df['release_date'])
print(df.index)
# Out:
# RangeIndex(start=0, stop=4803, step=1)

# %%
df['year'] = pd.DatetimeIndex(df['release_date']).year.fillna(0).astype('int64')

# %%
df.head(2)
# Out:
#       budget                                      homepage     id  \
# 0  237000000                   http://www.avatarmovie.com/  19995
# 1  300000000  http://disney.go.com/disneypictures/pirates/    285
#
#   original_language                            original_title  \
# 0                en                                    Avatar
# 1                en  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity release_date  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577   2009-12-10
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615   2007-05-19
#
#       revenue  runtime    status  \
# 0  2787965087    162.0  Released
# 1   961000000    169.0  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
#
#                                       title  vote_average  vote_count  year
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007

# %% [markdown]
# Оставим только интересующие нас годы: 1960, 1990, 2000, 2005, 2010, 2015

# %% [markdown]
# ПОсмотрим, как менялось количество релизов за весь период. Для этого используем plot в matplotlub (простой line chart).Переменные - дискретные

# %%
#Количество выпущенных фильмов по годам используем plot() в Pandas
df.groupby('year')['id'].count().plot(marker = '.')
xlim(1960,2016)
# Out:
# (1960, 2016)

# %%
df = df[df['year'].isin([1960, 1990, 2000, 2005, 2010, 2015])]

# %% [markdown]
# Оставим только топ-5 самых популярных жанров

# %%
#Покажем популярные жанры с помощью графика bar plot.Переменные - категориальные, цель - показать количество релизова по жанрам
sns.set()
plt.barh(df_merged['genre'].value_counts().reset_index()['index'],
        df_merged['genre'].value_counts().reset_index()['genre'], color = 'g')
plt.xlabel('Total count')
plt.show()

# %%
df_merged = pd.merge(df,genres,how = 'inner', left_on = 'id', right_on = 'movieid')

# %%
top_5_genres_lst = list(df_merged['genre'].value_counts().head().reset_index()['index'])
top_5_genres_lst
# Out:
# ['Action', 'Comedy', 'Drama', 'Adventure', 'Family']

# %%
df_merged_top_5_genre = df_merged[df_merged['genre'].isin(top_5_genres_lst)]
df_merged_top_5_genre.head(3)
# Out:
#       budget homepage  id_x original_language original_title  \
# 1  207000000            254                en      King Kong
# 2  207000000            254                en      King Kong
# 3  207000000            254                en      King Kong
#
#                                             overview  popularity release_date  \
# 1  In 1933 New York, an overly ambitious movie pr...    61.22601   2005-12-14
# 2  In 1933 New York, an overly ambitious movie pr...    61.22601   2005-12-14
# 3  In 1933 New York, an overly ambitious movie pr...    61.22601   2005-12-14
#
#      revenue  runtime    status                          tagline      title  \
# 1  550000000    187.0  Released  The eighth wonder of the world.  King Kong
# 2  550000000    187.0  Released  The eighth wonder of the world.  King Kong
# 3  550000000    187.0  Released  The eighth wonder of the world.  King Kong
#
#    vote_average  vote_count  year  movieid   id_y      genre
# 1           6.6        2337  2005      254  10751     Family
# 2           6.6        2337  2005      254     12  Adventure
# 3           6.6        2337  2005      254     35     Comedy

# %%
df_merged_top_5_genre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 191 entries, 1 to 320
# Data columns (total 19 columns):
# budget               191 non-null int64
# homepage             191 non-null object
# id_x                 191 non-null int64
# original_language    191 non-null object
# original_title       191 non-null object
# overview             191 non-null object
# popularity           191 non-null float64
# release_date         191 non-null datetime64[ns]
# revenue              191 non-null int64
# runtime              191 non-null float64
# status               191 non-null object
# tagline              191 non-null object
# title                191 non-null object
# vote_average         191 non-null float64
# vote_count           191 non-null int64
# year                 191 non-null int64
# movieid              191 non-null int64
# id_y                 191 non-null int64
# genre                191 non-null object
# dtypes: datetime64[ns](1), float64(3), int64(7), object(8)
# memory usage: 29.8+ KB

# %%
df_cmn = df_merged_top_5_genre.copy()

# %%
df_countries = pd.merge(df_merged_top_5_genre ,prod_country,how = 'inner', left_on = 'id_x', right_on = 'movieid')

# %%
df_cmn = df_countries.copy()

# %% [markdown]
# # Визуализация данных

# %% [markdown]
# #### Покажем,как менялось количество выпущенных фильмов по годам. Для этого используем Line chart. Переменные - дискретные

# %%
# %env BOKEH_RESOURCES=inline ipython notebook
from bokeh.io import show, output_notebook
from bokeh.plotting import ColumnDataSource, figure
from bokeh.models import HoverTool, Range1d

output_notebook()
# Out:
# env: BOKEH_RESOURCES=inline ipython notebook
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a8d0f542-906b-4930-a290-40bdd3f7de4a">Loading BokehJS ...</span>
#     </div>

# %%
years = sort(df['year'].unique())
years
# Out:
# array([1960, 1990, 2000, 2005, 2010, 2015], dtype=int64)

# %%
count_release = np.array(df.groupby('year')['id'].count().sort_values())

# %%
p = figure(x_axis_label='year', y_axis_label='release count')

p.line(years,count_release, line_width = 4)

p.circle(years,count_release, fill_color='white', size=10)
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="5cd6ba4b-d557-4cd0-bc5c-5972a9ba0da0"></div>
# </div>

# %% [markdown]
# #### Покажем, какой жанр фильмов был самым популярным по годам и вообщем за все время.Используем топ-5 ранее отобранных жанров.

# %%
count_genre_by_year = df_merged_top_5_genre.groupby(['year','genre']).count()
count_genre_by_year
# Out:
#                 budget  homepage  id_x  original_language  original_title  \
# year genre
# 1960 Action          1         1     1                  1               1
#      Adventure       1         1     1                  1               1
#      Comedy          1         1     1                  1               1
#      Family          1         1     1                  1               1
# 1990 Action          8         8     8                  8               8
#      Adventure       5         5     5                  5               5
#      Comedy          3         3     3                  3               3
#      Drama           4         4     4                  4               4
#      Family          5         5     5                  5               5
# 2000 Action         20        20    20                 20              20
#      Adventure      15        15    15                 15              15
#      Comedy         15        15    15                 15              15
#      Drama          14        14    14                 14              14
#      Family          8         8     8                  8               8
# 2005 Action         15        15    15                 15              15
#      Adventure      14        14    14                 14              14
#      Comedy         23        23    23                 23              23
#      Drama          22        22    22                 22              22
#      Family         16        16    16                 16              16
#
#                 overview  popularity  release_date  revenue  runtime  status  \
# year genre
# 1960 Action            1           1             1        1        1       1
#      Adventure         1           1             1        1        1       1
#      Comedy            1           1             1        1        1       1
#      Family            1           1             1        1        1       1
# 1990 Action            8           8             8        8        8       8
#      Adventure         5           5             5        5        5       5
#      Comedy            3           3             3        3        3       3
#      Drama             4           4             4        4        4       4
#      Family            5           5             5        5        5       5
# 2000 Action           20          20            20       20       20      20
#      Adventure        15          15            15       15       15      15
#      Comedy           15          15            15       15       15      15
#      Drama            14          14            14       14       14      14
#      Family            8           8             8        8        8       8
# 2005 Action           15          15            15       15       15      15
#      Adventure        14          14            14       14       14      14
#      Comedy           23          23            23       23       23      23
#      Drama            22          22            22       22       22      22
#      Family           16          16            16       16       16      16
#
#                 tagline  title  vote_average  vote_count  movieid  id_y
# year genre
# 1960 Action           1      1             1           1        1     1
#      Adventure        1      1             1           1        1     1
#      Comedy           1      1             1           1        1     1
#      Family           1      1             1           1        1     1
# 1990 Action           8      8             8           8        8     8
#      Adventure        5      5             5           5        5     5
#      Comedy           3      3             3           3        3     3
#      Drama            4      4             4           4        4     4
#      Family           5      5             5           5        5     5
# 2000 Action          20     20            20          20       20    20
#      Adventure       15     15            15          15       15    15
#      Comedy          15     15            15          15       15    15
#      Drama           14     14            14          14       14    14
#      Family           8      8             8           8        8     8
# 2005 Action          15     15            15          15       15    15
#      Adventure       14     14            14          14       14    14
#      Comedy          23     23            23          23       23    23
#      Drama           22     22            22          22       22    22
#      Family          16     16            16          16       16    16

# %%
df_year_genre = count_genre_by_year.reset_index().pivot(index = 'year', columns = 'genre', values = 'id_x').reset_index()
df_year_genre.fillna(0)
# Out:
# genre  year  Action  Adventure  Comedy  Drama  Family
# 0      1960     1.0        1.0     1.0    0.0     1.0
# 1      1990     8.0        5.0     3.0    4.0     5.0
# 2      2000    20.0       15.0    15.0   14.0     8.0
# 3      2005    15.0       14.0    23.0   22.0    16.0

# %%
_ = sns.swarmplot(x ='genre',y='year' ,data = df_merged_top_5_genre)
#покажем вначале распределение жанров по годам с помощью swarmplot.как можем видем, трудно что либо понять из получившегося графика

# %%
total_count_genre = df_merged_top_5_genre['genre'].value_counts().reset_index()
total_count_genre
# Out:
#        index  genre
# 0     Action     44
# 1     Comedy     42
# 2      Drama     40
# 3  Adventure     35
# 4     Family     30

# %%
from plotly.offline import init_notebook_mode, iplot
#простой import plotly не работает из-за конфликта имен
from plotly import plotly
import plotly.plotly as plt
import plotly.graph_objs as go
import plotly.offline

init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
#Для самого популярно жанра за всем время нарисуем Pie Chart. переменные категориальные. Покажет нам доли количества релизов жанров  от общего количества релизов
genre_total = list(total_count_genre['index'])
total_count = list(total_count_genre['genre'])


trace = go.Pie(labels=genre_total, values=total_count)

iplot([trace], show_link=False)
# Out:
# <div id="0d8adcf5-23d9-47f9-9418-d24ea9514adf" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0d8adcf5-23d9-47f9-9418-d24ea9514adf", [{"labels": ["Action", "Comedy", "Drama", "Adventure", "Family"], "values": [44, 42, 40, 35, 30], "type": "pie", "uid": "222261bc-4ecd-4cf8-a0b1-a1b6ecde478e"}], {}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("0d8adcf5-23d9-47f9-9418-d24ea9514adf"));});</script>

# %%
total_count_genre
# Out:
#        index  genre
# 0     Action     44
# 1     Comedy     42
# 2      Drama     40
# 3  Adventure     35
# 4     Family     30

# %%
df_merged_top_5_genre['year'].unique()
# Out:
# array([2005, 1990, 2000, 1960], dtype=int64)

# %%
#Для изменения количества релизова по жанрам нарисуем несколько pie charts  для каждого года. Сможем увидеть как менялись доли выпускаемых жанров по годам
df_genre_1960 = df_merged_top_5_genre[df_merged_top_5_genre['year'] == 1960]
df_genre_1990 = df_merged_top_5_genre[df_merged_top_5_genre['year'] == 1990]
df_genre_2000 = df_merged_top_5_genre[df_merged_top_5_genre['year'] == 2000]
df_genre_2005 = df_merged_top_5_genre[df_merged_top_5_genre['year'] == 2005]

df_genre_1960 = df_genre_1960['genre'].value_counts().reset_index()
df_genre_1990 = df_genre_1990['genre'].value_counts().reset_index()
df_genre_2000 = df_genre_2000['genre'].value_counts().reset_index()
df_genre_2005 = df_genre_2005['genre'].value_counts().reset_index()


genre_total_1960 = list(df_genre_1960['index'])
total_count_1960 = list(df_genre_1960['genre'])

genre_total_1990 = list(df_genre_1990['index'])
total_count_1990 = list(df_genre_1990['genre'])

genre_total_2000 = list(df_genre_2000['index'])
total_count_2000 = list(df_genre_2000['genre'])

genre_total_2005 = list(df_genre_2005['index'])
total_count_2005 = list(df_genre_2005['genre'])

# %%
fig = {
    'data': [
        {
            'labels': genre_total_1960,
            'values': total_count_1960,
            'type': 'pie',
            "hole": .4,
            'marker': {'colors': ['rgb(56, 75, 126)',
                                  'rgb(18, 36, 37)',
                                  'rgb(34, 53, 101)',
                                  'rgb(36, 55, 57)',
                                  'rgb(6, 4, 4)']},
            'domain': {'x': [0, .48],
                       'y': [0, .49]},
            'hoverinfo':'label+percent+name',
            "text":[""],
            "textposition":"inside"
    
        },
        {
            'labels': genre_total_1990,
            'values': total_count_1990,
            'marker': {'colors': ['rgb(56, 75, 126)',
                                  'rgb(18, 36, 37)',
                                  'rgb(34, 53, 101)',
                                  'rgb(36, 55, 57)',
                                  'rgb(6, 4, 4)']},
            'type': 'pie',
            "hole": .4,
            'name': '1990',
            'domain': {'x': [.52, 1],
                       'y': [0, .49]},
            'hoverinfo':'label+percent+name',
            "text":[""],
            "textposition":"inside"

        },
        {
            'labels': genre_total_2000,
            'values': total_count_2000,
            'marker': {'colors': ['rgb(56, 75, 126)',
                                  'rgb(18, 36, 37)',
                                  'rgb(34, 53, 101)',
                                  'rgb(36, 55, 57)',
                                  'rgb(6, 4, 4)']},
            'type': 'pie',
            "hole": .4,
            'name': '2000',
            'domain': {'x': [0, .48],
                       'y': [.51, 1]},
            'hoverinfo':'label+percent+name',
            "text":[""],
            "textposition":"inside"
        },
        {
            'labels': genre_total_2005,
            'values': total_count_2005,
            'marker': {'colors': ['rgb(56, 75, 126)',
                                  'rgb(18, 36, 37)',
                                  'rgb(34, 53, 101)',
                                  'rgb(36, 55, 57)',
                                  'rgb(6, 4, 4)']},
            'type': 'pie',
            'name':'2005',
            "hole": .4,
            'domain': {'x': [.52, 1],
                       'y': [.51, 1]},
            'hoverinfo':'label+percent+name',
            "text":[""],
            "textposition":"inside"
        }
    ],
    'layout': {'title': 'Total counts per genres by years',
               'showlegend': True,
               "annotations": [
            {
                "font": {
                    "size": 20
                },
                "showarrow": False,
                "text": "2000",
                "x": 0.205,
                "y": 0.8
            },
            {
                "font": {
                    "size": 20
                },
                "showarrow": False,
                "text": "2005",
                "x": 0.8,
                "y": 0.8
            }
                   ,{
                "font": {
                    "size": 20
                },
                "showarrow": False,
                "text": "1990",
                "x": 0.797,
                "y": 0.21
            }
                   ,{
                "font": {
                    "size": 20
                },
                "showarrow": False,
                "text": "1960",
                "x": 0.205,
                "y": 0.21
            }
        ]}
}

iplot(fig,  show_link=False)
# Out:
# <div id="23ccf790-b84e-4a1a-9d10-a768c4eb9fc0" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("23ccf790-b84e-4a1a-9d10-a768c4eb9fc0", [{"domain": {"x": [0, 0.48], "y": [0, 0.49]}, "hole": 0.4, "hoverinfo": "label+percent+name", "labels": ["Adventure", "Action", "Family", "Comedy"], "marker": {"colors": ["rgb(56, 75, 126)", "rgb(18, 36, 37)", "rgb(34, 53, 101)", "rgb(36, 55, 57)", "rgb(6, 4, 4)"]}, "text": [""], "textposition": "inside", "values": [1, 1, 1, 1], "type": "pie", "uid": "170757db-8ad3-4681-8032-3f480729ddac"}, {"domain": {"x": [0.52, 1], "y": [0, 0.49]}, "hole": 0.4, "hoverinfo": "label+percent+name", "labels": ["Action", "Adventure", "Family", "Drama", "Comedy"], "marker": {"colors": ["rgb(56, 75, 126)", "rgb(18, 36, 37)", "rgb(34, 53, 101)", "rgb(36, 55, 57)", "rgb(6, 4, 4)"]}, "name": "1990", "text": [""], "textposition": "inside", "values": [8, 5, 5, 4, 3], "type": "pie", "uid": "3cf3d5e6-6b1b-4cf4-ac6e-695497c1d94a"}, {"domain": {"x": [0, 0.48], "y": [0.51, 1]}, "hole": 0.4, "hoverinfo": "label+percent+name", "labels": ["Action", "Adventure", "Comedy", "Drama", "Family"], "marker": {"colors": ["rgb(56, 75, 126)", "rgb(18, 36, 37)", "rgb(34, 53, 101)", "rgb(36, 55, 57)", "rgb(6, 4, 4)"]}, "name": "2000", "text": [""], "textposition": "inside", "values": [20, 15, 15, 14, 8], "type": "pie", "uid": "a0b21551-3cc8-410d-a722-4014f5f60292"}, {"domain": {"x": [0.52, 1], "y": [0.51, 1]}, "hole": 0.4, "hoverinfo": "label+percent+name", "labels": ["Comedy", "Drama", "Family", "Action", "Adventure"], "marker": {"colors": ["rgb(56, 75, 126)", "rgb(18, 36, 37)", "rgb(34, 53, 101)", "rgb(36, 55, 57)", "rgb(6, 4, 4)"]}, "name": "2005", "text": [""], "textposition": "inside", "values": [23, 22, 16, 15, 14], "type": "pie", "uid": "bb6eb922-c691-49ec-af97-f8e19a98db4d"}], {"annotations": [{"font": {"size": 20}, "showarrow": false, "text": "2000", "x": 0.205, "y": 0.8}, {"font": {"size": 20}, "showarrow": false, "text": "2005", "x": 0.8, "y": 0.8}, {"font": {"size": 20}, "showarrow": false, "text": "1990", "x": 0.797, "y": 0.21}, {"font": {"size": 20}, "showarrow": false, "text": "1960", "x": 0.205, "y": 0.21}], "showlegend": true, "title": "Total counts per genres by years"}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("23ccf790-b84e-4a1a-9d10-a768c4eb9fc0"));});</script>

# %% [markdown]
# #### Посмотрим, коррелируют ли между собой выручка, бюджет, время фильма, среднее оценка.Для этого используем heatmap

# %%
df.columns
# Out:
# Index(['budget', 'homepage', 'id', 'original_language', 'original_title',
#        'overview', 'popularity', 'release_date', 'revenue', 'runtime',
#        'status', 'tagline', 'title', 'vote_average', 'vote_count', 'year'],
#       dtype='object')

# %%
sns.heatmap(df[['budget','revenue','runtime','vote_average']].corr())
